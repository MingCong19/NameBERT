# %%
from pathlib import Path
import re, json, unicodedata, string
from collections import Counter, defaultdict
from tqdm import tqdm

# INPUT: where your *.filtered.jsonl batches live
INPUT_DIR  = Path(r"C:\Users\XxRui\Desktop\newData\output")
# OUTPUT: where to write merged batches (1:1 filenames)
OUTPUT_DIR = INPUT_DIR / "country_merged_batches"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Only process part00000 … part00300 (inclusive)
START_IDX, END_IDX = 0, 300

# %%
def strip_accents(s: str) -> str:
    return "".join(c for c in unicodedata.normalize("NFKD", s) if not unicodedata.combining(c))

PUNC_TABLE = str.maketrans("", "", string.punctuation)

def norm_key(s: str) -> str:
    """Lowercase, remove punctuation and extra spaces."""
    if not s:
        return ""
    s = strip_accents(s)
    s = s.lower().translate(PUNC_TABLE)
    s = re.sub(r"\s+", " ", s).strip()
    return s

# %%
ALIASES = defaultdict(lambda: None)

def add_alias(alias, canonical):
    ALIASES[norm_key(alias)] = canonical.lower()

# --- Merged canonical forms (all lowercase) ---

# united states
for a in ["usa","u.s.a.","u.s.","us","united states","united states of america","america"]:
    add_alias(a, "usa")

# china (includes hong kong, macau)
for a in [
    "china","prc","people's republic of china","peoples republic of china",
    "中国","中國","zhongguo",
    "hong kong","香港","香港特別行政區","xianggang","香港特别行政区",
    "macau","macao","澳门","澳門","aomen","澳門特別行政區","澳门特别行政区"
]:
    add_alias(a, "china")

# taiwan (ROC)
for a in ["taiwan","台灣","臺灣","republic of china","roc","r.o.c."]:
    add_alias(a, "taiwan")

for a in ["polska"]:
    add_alias(a, "poland")
    
for a in ["日本"]:
    add_alias(a, "japan")

for a in ["magyarorszag"]:
    add_alias(a, "hungary")

for a in ["uae"]:
    add_alias(a, "united arab emirates")    

# korea
for a in ["south korea","republic of korea","korea","대한민국"]:
    add_alias(a, "south korea")
for a in ["north korea","dprk","democratic people's republic of korea"]:
    add_alias(a, "north korea")

# uk and home nations
for a in ["uk","u.k.","united kingdom","great britain","gb","g.b.","england","scotland","wales","northern ireland"]:
    add_alias(a, "united kingdom")

# russia
for a in ["russia","russian federation","россия","российская федерация","rossiyskaya federatsiya"]:
    add_alias(a, "russia")

# european and language variants
alias_pairs = {
    "méxico": "mexico", "brasil": "brazil", "deutschland": "germany",
    "sverige": "sweden", "österreich": "austria", "schweiz": "switzerland",
    "suomi": "finland", "norge": "norway", "danmark": "denmark",
    "españa": "spain", "italia": "italy", "the netherlands": "netherlands",
    "côte d’ivoire": "côte d’ivoire", "cote d’ivoire": "côte d’ivoire",
    "cote d'ivoire": "côte d’ivoire", "ivory coast": "côte d’ivoire"
}
for k, v in alias_pairs.items():
    add_alias(k, v)

# %%
def normalize_country_to_canonical(country_raw: str) -> str:
    """Return lowercase canonical country name."""
    if not country_raw:
        return ""
    key = norm_key(country_raw)

    canon = ALIASES.get(key)
    if canon:
        return canon

    # fallback: remove periods
    key2 = key.replace(".", "")
    canon = ALIASES.get(key2)
    if canon:
        return canon

    if key.startswith("the "):
        canon = ALIASES.get(key[4:])
        if canon:
            return canon

    # Default: normalized lowercase itself
    return key

# %%
def part_index_from_name(name: str):
    m = re.search(r"\.part(\d{5})\.filtered\.jsonl$", name)
    return int(m.group(1)) if m else None

def out_path_for(in_path: Path) -> Path:
    return OUTPUT_DIR / in_path.name.replace(".filtered.jsonl", ".country_merged.jsonl")

files = sorted(INPUT_DIR.glob("v3.1_oag_author.part*.filtered.jsonl"))

total_in, total_out = 0, 0
merged_counter = Counter()
unknown_samples = Counter()

for fp in files:
    idx = part_index_from_name(fp.name)
    if idx is None or not (START_IDX <= idx <= END_IDX):
        continue

    out_fp = out_path_for(fp)
    written = 0

    with fp.open("r", encoding="utf-8", errors="ignore") as fin, \
         out_fp.open("w", encoding="utf-8") as fout:

        for line in fin:
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
            except Exception:
                continue

            total_in += 1
            raw_country = obj.get("country") or ""
            merged = normalize_country_to_canonical(raw_country)
            obj["country"] = merged.lower()

            fout.write(json.dumps(obj, ensure_ascii=False) + "\n")
            written += 1
            total_out += 1
            merged_counter[merged] += 1

    print(f"✓ {fp.name} → {out_fp.name} ({written} records)")

print(f"\n✅ Done. Processed {total_in:,} records, wrote {total_out:,} records.")
# Out:
# ✓ v3.1_oag_author.part00000.filtered.jsonl → v3.1_oag_author.part00000.country_merged.jsonl (7296 records)
# ✓ v3.1_oag_author.part00001.filtered.jsonl → v3.1_oag_author.part00001.country_merged.jsonl (4951 records)
# ✓ v3.1_oag_author.part00002.filtered.jsonl → v3.1_oag_author.part00002.country_merged.jsonl (3098 records)
# ✓ v3.1_oag_author.part00003.filtered.jsonl → v3.1_oag_author.part00003.country_merged.jsonl (3922 records)
# ✓ v3.1_oag_author.part00004.filtered.jsonl → v3.1_oag_author.part00004.country_merged.jsonl (6736 records)
# ✓ v3.1_oag_author.part00005.filtered.jsonl → v3.1_oag_author.part00005.country_merged.jsonl (3924 records)
# ✓ v3.1_oag_author.part00006.filtered.jsonl → v3.1_oag_author.part00006.country_merged.jsonl (1538 records)
# ✓ v3.1_oag_author.part00007.filtered.jsonl → v3.1_oag_author.part00007.country_merged.jsonl (6689 records)
# ✓ v3.1_oag_author.part00008.filtered.jsonl → v3.1_oag_author.part00008.country_merged.jsonl (5295 records)
# ✓ v3.1_oag_author.part00009.filtered.jsonl → v3.1_oag_author.part00009.country_merged.jsonl (3689 records)
# ✓ v3.1_oag_author.part00010.filtered.jsonl → v3.1_oag_author.part00010.country_merged.jsonl (2809 records)
# ✓ v3.1_oag_author.part00011.filtered.jsonl → v3.1_oag_author.part00011.country_merged.jsonl (7000 records)
# ✓ v3.1_oag_author.part00012.filtered.jsonl → v3.1_oag_author.part00012.country_merged.jsonl (4351 records)
# ✓ v3.1_oag_author.part00013.filtered.jsonl → v3.1_oag_author.part00013.country_merged.jsonl (1983 records)
# ✓ v3.1_oag_author.part00014.filtered.jsonl → v3.1_oag_author.part00014.country_merged.jsonl (6085 records)
# ✓ v3.1_oag_author.part00015.filtered.jsonl → v3.1_oag_author.part00015.country_merged.jsonl (5843 records)
# ✓ v3.1_oag_author.part00016.filtered.jsonl → v3.1_oag_author.part00016.country_merged.jsonl (3594 records)
# ✓ v3.1_oag_author.part00017.filtered.jsonl → v3.1_oag_author.part00017.country_merged.jsonl (2078 records)
# ✓ v3.1_oag_author.part00018.filtered.jsonl → v3.1_oag_author.part00018.country_merged.jsonl (5602 records)
# ✓ v3.1_oag_author.part00019.filtered.jsonl → v3.1_oag_author.part00019.country_merged.jsonl (4090 records)
# ✓ v3.1_oag_author.part00020.filtered.jsonl → v3.1_oag_author.part00020.country_merged.jsonl (4793 records)
# ✓ v3.1_oag_author.part00021.filtered.jsonl → v3.1_oag_author.part00021.country_merged.jsonl (4557 records)
# ✓ v3.1_oag_author.part00022.filtered.jsonl → v3.1_oag_author.part00022.country_merged.jsonl (3803 records)
# ✓ v3.1_oag_author.part00023.filtered.jsonl → v3.1_oag_author.part00023.country_merged.jsonl (5700 records)
# ✓ v3.1_oag_author.part00024.filtered.jsonl → v3.1_oag_author.part00024.country_merged.jsonl (2507 records)
# ✓ v3.1_oag_author.part00025.filtered.jsonl → v3.1_oag_author.part00025.country_merged.jsonl (6066 records)
# ✓ v3.1_oag_author.part00026.filtered.jsonl → v3.1_oag_author.part00026.country_merged.jsonl (3517 records)
# ✓ v3.1_oag_author.part00027.filtered.jsonl → v3.1_oag_author.part00027.country_merged.jsonl (5573 records)
# ✓ v3.1_oag_author.part00028.filtered.jsonl → v3.1_oag_author.part00028.country_merged.jsonl (4036 records)
# ✓ v3.1_oag_author.part00029.filtered.jsonl → v3.1_oag_author.part00029.country_merged.jsonl (4444 records)
# ✓ v3.1_oag_author.part00030.filtered.jsonl → v3.1_oag_author.part00030.country_merged.jsonl (4670 records)
# ✓ v3.1_oag_author.part00031.filtered.jsonl → v3.1_oag_author.part00031.country_merged.jsonl (3474 records)
# ✓ v3.1_oag_author.part00032.filtered.jsonl → v3.1_oag_author.part00032.country_merged.jsonl (6522 records)
# ✓ v3.1_oag_author.part00033.filtered.jsonl → v3.1_oag_author.part00033.country_merged.jsonl (5323 records)
# ✓ v3.1_oag_author.part00034.filtered.jsonl → v3.1_oag_author.part00034.country_merged.jsonl (3598 records)
# ✓ v3.1_oag_author.part00035.filtered.jsonl → v3.1_oag_author.part00035.country_merged.jsonl (2729 records)
# ✓ v3.1_oag_author.part00036.filtered.jsonl → v3.1_oag_author.part00036.country_merged.jsonl (6975 records)
# ✓ v3.1_oag_author.part00037.filtered.jsonl → v3.1_oag_author.part00037.country_merged.jsonl (4465 records)
# ✓ v3.1_oag_author.part00038.filtered.jsonl → v3.1_oag_author.part00038.country_merged.jsonl (2204 records)
# ✓ v3.1_oag_author.part00039.filtered.jsonl → v3.1_oag_author.part00039.country_merged.jsonl (5861 records)
# ✓ v3.1_oag_author.part00040.filtered.jsonl → v3.1_oag_author.part00040.country_merged.jsonl (5984 records)
# ✓ v3.1_oag_author.part00041.filtered.jsonl → v3.1_oag_author.part00041.country_merged.jsonl (3579 records)
# ✓ v3.1_oag_author.part00042.filtered.jsonl → v3.1_oag_author.part00042.country_merged.jsonl (1793 records)
# ✓ v3.1_oag_author.part00043.filtered.jsonl → v3.1_oag_author.part00043.country_merged.jsonl (7019 records)
# ✓ v3.1_oag_author.part00044.filtered.jsonl → v3.1_oag_author.part00044.country_merged.jsonl (4711 records)
# ✓ v3.1_oag_author.part00045.filtered.jsonl → v3.1_oag_author.part00045.country_merged.jsonl (2797 records)
# ✓ v3.1_oag_author.part00046.filtered.jsonl → v3.1_oag_author.part00046.country_merged.jsonl (4605 records)
# ✓ v3.1_oag_author.part00047.filtered.jsonl → v3.1_oag_author.part00047.country_merged.jsonl (6849 records)
# ✓ v3.1_oag_author.part00048.filtered.jsonl → v3.1_oag_author.part00048.country_merged.jsonl (3803 records)
# ✓ v3.1_oag_author.part00049.filtered.jsonl → v3.1_oag_author.part00049.country_merged.jsonl (1152 records)
# ✓ v3.1_oag_author.part00050.filtered.jsonl → v3.1_oag_author.part00050.country_merged.jsonl (7082 records)
# ✓ v3.1_oag_author.part00051.filtered.jsonl → v3.1_oag_author.part00051.country_merged.jsonl (4881 records)
# ✓ v3.1_oag_author.part00052.filtered.jsonl → v3.1_oag_author.part00052.country_merged.jsonl (3462 records)
# ✓ v3.1_oag_author.part00053.filtered.jsonl → v3.1_oag_author.part00053.country_merged.jsonl (3514 records)
# ✓ v3.1_oag_author.part00054.filtered.jsonl → v3.1_oag_author.part00054.country_merged.jsonl (6932 records)
# ✓ v3.1_oag_author.part00055.filtered.jsonl → v3.1_oag_author.part00055.country_merged.jsonl (3984 records)
# ✓ v3.1_oag_author.part00056.filtered.jsonl → v3.1_oag_author.part00056.country_merged.jsonl (1750 records)
# ✓ v3.1_oag_author.part00057.filtered.jsonl → v3.1_oag_author.part00057.country_merged.jsonl (6317 records)
# ✓ v3.1_oag_author.part00058.filtered.jsonl → v3.1_oag_author.part00058.country_merged.jsonl (5613 records)
# ✓ v3.1_oag_author.part00059.filtered.jsonl → v3.1_oag_author.part00059.country_merged.jsonl (3436 records)
# ✓ v3.1_oag_author.part00060.filtered.jsonl → v3.1_oag_author.part00060.country_merged.jsonl (2456 records)
# ✓ v3.1_oag_author.part00061.filtered.jsonl → v3.1_oag_author.part00061.country_merged.jsonl (6721 records)
# ✓ v3.1_oag_author.part00062.filtered.jsonl → v3.1_oag_author.part00062.country_merged.jsonl (4690 records)
# ✓ v3.1_oag_author.part00063.filtered.jsonl → v3.1_oag_author.part00063.country_merged.jsonl (2365 records)
# ✓ v3.1_oag_author.part00064.filtered.jsonl → v3.1_oag_author.part00064.country_merged.jsonl (5384 records)
# ✓ v3.1_oag_author.part00065.filtered.jsonl → v3.1_oag_author.part00065.country_merged.jsonl (6321 records)
# ✓ v3.1_oag_author.part00066.filtered.jsonl → v3.1_oag_author.part00066.country_merged.jsonl (3721 records)
# ✓ v3.1_oag_author.part00067.filtered.jsonl → v3.1_oag_author.part00067.country_merged.jsonl (1465 records)
# ✓ v3.1_oag_author.part00068.filtered.jsonl → v3.1_oag_author.part00068.country_merged.jsonl (7126 records)
# ✓ v3.1_oag_author.part00069.filtered.jsonl → v3.1_oag_author.part00069.country_merged.jsonl (4888 records)
# ✓ v3.1_oag_author.part00070.filtered.jsonl → v3.1_oag_author.part00070.country_merged.jsonl (2980 records)
# ✓ v3.1_oag_author.part00071.filtered.jsonl → v3.1_oag_author.part00071.country_merged.jsonl (4183 records)
# ✓ v3.1_oag_author.part00072.filtered.jsonl → v3.1_oag_author.part00072.country_merged.jsonl (6716 records)
# ✓ v3.1_oag_author.part00073.filtered.jsonl → v3.1_oag_author.part00073.country_merged.jsonl (3993 records)
# ✓ v3.1_oag_author.part00074.filtered.jsonl → v3.1_oag_author.part00074.country_merged.jsonl (1359 records)
# ✓ v3.1_oag_author.part00075.filtered.jsonl → v3.1_oag_author.part00075.country_merged.jsonl (7102 records)
# ✓ v3.1_oag_author.part00076.filtered.jsonl → v3.1_oag_author.part00076.country_merged.jsonl (5047 records)
# ✓ v3.1_oag_author.part00077.filtered.jsonl → v3.1_oag_author.part00077.country_merged.jsonl (3646 records)
# ✓ v3.1_oag_author.part00078.filtered.jsonl → v3.1_oag_author.part00078.country_merged.jsonl (2895 records)
# ✓ v3.1_oag_author.part00079.filtered.jsonl → v3.1_oag_author.part00079.country_merged.jsonl (6809 records)
# ✓ v3.1_oag_author.part00080.filtered.jsonl → v3.1_oag_author.part00080.country_merged.jsonl (4362 records)
# ✓ v3.1_oag_author.part00081.filtered.jsonl → v3.1_oag_author.part00081.country_merged.jsonl (2033 records)
# ✓ v3.1_oag_author.part00082.filtered.jsonl → v3.1_oag_author.part00082.country_merged.jsonl (6113 records)
# ✓ v3.1_oag_author.part00083.filtered.jsonl → v3.1_oag_author.part00083.country_merged.jsonl (5951 records)
# ✓ v3.1_oag_author.part00084.filtered.jsonl → v3.1_oag_author.part00084.country_merged.jsonl (3517 records)
# ✓ v3.1_oag_author.part00085.filtered.jsonl → v3.1_oag_author.part00085.country_merged.jsonl (1990 records)
# ✓ v3.1_oag_author.part00086.filtered.jsonl → v3.1_oag_author.part00086.country_merged.jsonl (6826 records)
# ✓ v3.1_oag_author.part00087.filtered.jsonl → v3.1_oag_author.part00087.country_merged.jsonl (4896 records)
# ✓ v3.1_oag_author.part00088.filtered.jsonl → v3.1_oag_author.part00088.country_merged.jsonl (2577 records)
# ✓ v3.1_oag_author.part00089.filtered.jsonl → v3.1_oag_author.part00089.country_merged.jsonl (4914 records)
# ✓ v3.1_oag_author.part00090.filtered.jsonl → v3.1_oag_author.part00090.country_merged.jsonl (6485 records)
# ✓ v3.1_oag_author.part00091.filtered.jsonl → v3.1_oag_author.part00091.country_merged.jsonl (3728 records)
# ✓ v3.1_oag_author.part00092.filtered.jsonl → v3.1_oag_author.part00092.country_merged.jsonl (1093 records)
# ✓ v3.1_oag_author.part00093.filtered.jsonl → v3.1_oag_author.part00093.country_merged.jsonl (7218 records)
# ✓ v3.1_oag_author.part00094.filtered.jsonl → v3.1_oag_author.part00094.country_merged.jsonl (4973 records)
# ✓ v3.1_oag_author.part00095.filtered.jsonl → v3.1_oag_author.part00095.country_merged.jsonl (3136 records)
# ✓ v3.1_oag_author.part00096.filtered.jsonl → v3.1_oag_author.part00096.country_merged.jsonl (3997 records)
# ✓ v3.1_oag_author.part00097.filtered.jsonl → v3.1_oag_author.part00097.country_merged.jsonl (6855 records)
# ✓ v3.1_oag_author.part00098.filtered.jsonl → v3.1_oag_author.part00098.country_merged.jsonl (3914 records)
# ✓ v3.1_oag_author.part00099.filtered.jsonl → v3.1_oag_author.part00099.country_merged.jsonl (1575 records)
# ✓ v3.1_oag_author.part00100.filtered.jsonl → v3.1_oag_author.part00100.country_merged.jsonl (6605 records)
# ✓ v3.1_oag_author.part00101.filtered.jsonl → v3.1_oag_author.part00101.country_merged.jsonl (5282 records)
# ✓ v3.1_oag_author.part00102.filtered.jsonl → v3.1_oag_author.part00102.country_merged.jsonl (3593 records)
# ✓ v3.1_oag_author.part00103.filtered.jsonl → v3.1_oag_author.part00103.country_merged.jsonl (2863 records)
# ✓ v3.1_oag_author.part00104.filtered.jsonl → v3.1_oag_author.part00104.country_merged.jsonl (6873 records)
# ✓ v3.1_oag_author.part00105.filtered.jsonl → v3.1_oag_author.part00105.country_merged.jsonl (4352 records)
# ✓ v3.1_oag_author.part00106.filtered.jsonl → v3.1_oag_author.part00106.country_merged.jsonl (2066 records)
# ✓ v3.1_oag_author.part00107.filtered.jsonl → v3.1_oag_author.part00107.country_merged.jsonl (6116 records)
# ✓ v3.1_oag_author.part00108.filtered.jsonl → v3.1_oag_author.part00108.country_merged.jsonl (6003 records)
# ✓ v3.1_oag_author.part00109.filtered.jsonl → v3.1_oag_author.part00109.country_merged.jsonl (3600 records)
# ✓ v3.1_oag_author.part00110.filtered.jsonl → v3.1_oag_author.part00110.country_merged.jsonl (1795 records)
# ✓ v3.1_oag_author.part00111.filtered.jsonl → v3.1_oag_author.part00111.country_merged.jsonl (7128 records)
# ✓ v3.1_oag_author.part00112.filtered.jsonl → v3.1_oag_author.part00112.country_merged.jsonl (4860 records)
# ✓ v3.1_oag_author.part00113.filtered.jsonl → v3.1_oag_author.part00113.country_merged.jsonl (2678 records)
# ✓ v3.1_oag_author.part00114.filtered.jsonl → v3.1_oag_author.part00114.country_merged.jsonl (4836 records)
# ✓ v3.1_oag_author.part00115.filtered.jsonl → v3.1_oag_author.part00115.country_merged.jsonl (6634 records)
# ✓ v3.1_oag_author.part00116.filtered.jsonl → v3.1_oag_author.part00116.country_merged.jsonl (3866 records)
# ✓ v3.1_oag_author.part00117.filtered.jsonl → v3.1_oag_author.part00117.country_merged.jsonl (1191 records)
# ✓ v3.1_oag_author.part00118.filtered.jsonl → v3.1_oag_author.part00118.country_merged.jsonl (7084 records)
# ✓ v3.1_oag_author.part00119.filtered.jsonl → v3.1_oag_author.part00119.country_merged.jsonl (4966 records)
# ✓ v3.1_oag_author.part00120.filtered.jsonl → v3.1_oag_author.part00120.country_merged.jsonl (3004 records)
# ✓ v3.1_oag_author.part00121.filtered.jsonl → v3.1_oag_author.part00121.country_merged.jsonl (3798 records)
# ✓ v3.1_oag_author.part00122.filtered.jsonl → v3.1_oag_author.part00122.country_merged.jsonl (6878 records)
# ✓ v3.1_oag_author.part00123.filtered.jsonl → v3.1_oag_author.part00123.country_merged.jsonl (3945 records)
# ✓ v3.1_oag_author.part00124.filtered.jsonl → v3.1_oag_author.part00124.country_merged.jsonl (1620 records)
# ✓ v3.1_oag_author.part00125.filtered.jsonl → v3.1_oag_author.part00125.country_merged.jsonl (6636 records)
# ✓ v3.1_oag_author.part00126.filtered.jsonl → v3.1_oag_author.part00126.country_merged.jsonl (5398 records)
# ✓ v3.1_oag_author.part00127.filtered.jsonl → v3.1_oag_author.part00127.country_merged.jsonl (3601 records)
# ✓ v3.1_oag_author.part00128.filtered.jsonl → v3.1_oag_author.part00128.country_merged.jsonl (2735 records)
# ✓ v3.1_oag_author.part00129.filtered.jsonl → v3.1_oag_author.part00129.country_merged.jsonl (7005 records)
# ✓ v3.1_oag_author.part00130.filtered.jsonl → v3.1_oag_author.part00130.country_merged.jsonl (4353 records)
# ✓ v3.1_oag_author.part00131.filtered.jsonl → v3.1_oag_author.part00131.country_merged.jsonl (2167 records)
# ✓ v3.1_oag_author.part00132.filtered.jsonl → v3.1_oag_author.part00132.country_merged.jsonl (5947 records)
# ✓ v3.1_oag_author.part00133.filtered.jsonl → v3.1_oag_author.part00133.country_merged.jsonl (6057 records)
# ✓ v3.1_oag_author.part00134.filtered.jsonl → v3.1_oag_author.part00134.country_merged.jsonl (3590 records)
# ✓ v3.1_oag_author.part00135.filtered.jsonl → v3.1_oag_author.part00135.country_merged.jsonl (1804 records)
# ✓ v3.1_oag_author.part00136.filtered.jsonl → v3.1_oag_author.part00136.country_merged.jsonl (6989 records)
# ✓ v3.1_oag_author.part00137.filtered.jsonl → v3.1_oag_author.part00137.country_merged.jsonl (4991 records)
# ✓ v3.1_oag_author.part00138.filtered.jsonl → v3.1_oag_author.part00138.country_merged.jsonl (2707 records)
# ✓ v3.1_oag_author.part00139.filtered.jsonl → v3.1_oag_author.part00139.country_merged.jsonl (4710 records)
# ✓ v3.1_oag_author.part00140.filtered.jsonl → v3.1_oag_author.part00140.country_merged.jsonl (6681 records)
# ✓ v3.1_oag_author.part00141.filtered.jsonl → v3.1_oag_author.part00141.country_merged.jsonl (3760 records)
# ✓ v3.1_oag_author.part00142.filtered.jsonl → v3.1_oag_author.part00142.country_merged.jsonl (1184 records)
# ✓ v3.1_oag_author.part00143.filtered.jsonl → v3.1_oag_author.part00143.country_merged.jsonl (7335 records)
# ✓ v3.1_oag_author.part00144.filtered.jsonl → v3.1_oag_author.part00144.country_merged.jsonl (4967 records)
# ✓ v3.1_oag_author.part00145.filtered.jsonl → v3.1_oag_author.part00145.country_merged.jsonl (3379 records)
# ✓ v3.1_oag_author.part00146.filtered.jsonl → v3.1_oag_author.part00146.country_merged.jsonl (3377 records)
# ✓ v3.1_oag_author.part00147.filtered.jsonl → v3.1_oag_author.part00147.country_merged.jsonl (7085 records)
# ✓ v3.1_oag_author.part00148.filtered.jsonl → v3.1_oag_author.part00148.country_merged.jsonl (4029 records)
# ✓ v3.1_oag_author.part00149.filtered.jsonl → v3.1_oag_author.part00149.country_merged.jsonl (1725 records)
# ✓ v3.1_oag_author.part00150.filtered.jsonl → v3.1_oag_author.part00150.country_merged.jsonl (6392 records)
# ✓ v3.1_oag_author.part00151.filtered.jsonl → v3.1_oag_author.part00151.country_merged.jsonl (5701 records)
# ✓ v3.1_oag_author.part00152.filtered.jsonl → v3.1_oag_author.part00152.country_merged.jsonl (3471 records)
# ✓ v3.1_oag_author.part00153.filtered.jsonl → v3.1_oag_author.part00153.country_merged.jsonl (2412 records)
# ✓ v3.1_oag_author.part00154.filtered.jsonl → v3.1_oag_author.part00154.country_merged.jsonl (6766 records)
# ✓ v3.1_oag_author.part00155.filtered.jsonl → v3.1_oag_author.part00155.country_merged.jsonl (4694 records)
# ✓ v3.1_oag_author.part00156.filtered.jsonl → v3.1_oag_author.part00156.country_merged.jsonl (2399 records)
# ✓ v3.1_oag_author.part00157.filtered.jsonl → v3.1_oag_author.part00157.country_merged.jsonl (5476 records)
# ✓ v3.1_oag_author.part00158.filtered.jsonl → v3.1_oag_author.part00158.country_merged.jsonl (6362 records)
# ✓ v3.1_oag_author.part00159.filtered.jsonl → v3.1_oag_author.part00159.country_merged.jsonl (3744 records)
# ✓ v3.1_oag_author.part00160.filtered.jsonl → v3.1_oag_author.part00160.country_merged.jsonl (1372 records)
# ✓ v3.1_oag_author.part00161.filtered.jsonl → v3.1_oag_author.part00161.country_merged.jsonl (7255 records)
# ✓ v3.1_oag_author.part00162.filtered.jsonl → v3.1_oag_author.part00162.country_merged.jsonl (4986 records)
# ✓ v3.1_oag_author.part00163.filtered.jsonl → v3.1_oag_author.part00163.country_merged.jsonl (3005 records)
# ✓ v3.1_oag_author.part00164.filtered.jsonl → v3.1_oag_author.part00164.country_merged.jsonl (4309 records)
# ✓ v3.1_oag_author.part00165.filtered.jsonl → v3.1_oag_author.part00165.country_merged.jsonl (6721 records)
# ✓ v3.1_oag_author.part00166.filtered.jsonl → v3.1_oag_author.part00166.country_merged.jsonl (3920 records)
# ✓ v3.1_oag_author.part00167.filtered.jsonl → v3.1_oag_author.part00167.country_merged.jsonl (1448 records)
# ✓ v3.1_oag_author.part00168.filtered.jsonl → v3.1_oag_author.part00168.country_merged.jsonl (6983 records)
# ✓ v3.1_oag_author.part00169.filtered.jsonl → v3.1_oag_author.part00169.country_merged.jsonl (5201 records)
# ✓ v3.1_oag_author.part00170.filtered.jsonl → v3.1_oag_author.part00170.country_merged.jsonl (3524 records)
# ✓ v3.1_oag_author.part00171.filtered.jsonl → v3.1_oag_author.part00171.country_merged.jsonl (2944 records)
# ✓ v3.1_oag_author.part00172.filtered.jsonl → v3.1_oag_author.part00172.country_merged.jsonl (7138 records)
# ✓ v3.1_oag_author.part00173.filtered.jsonl → v3.1_oag_author.part00173.country_merged.jsonl (4242 records)
# ✓ v3.1_oag_author.part00174.filtered.jsonl → v3.1_oag_author.part00174.country_merged.jsonl (1993 records)
# ✓ v3.1_oag_author.part00175.filtered.jsonl → v3.1_oag_author.part00175.country_merged.jsonl (6097 records)
# ✓ v3.1_oag_author.part00176.filtered.jsonl → v3.1_oag_author.part00176.country_merged.jsonl (5911 records)
# ✓ v3.1_oag_author.part00177.filtered.jsonl → v3.1_oag_author.part00177.country_merged.jsonl (3451 records)
# ✓ v3.1_oag_author.part00178.filtered.jsonl → v3.1_oag_author.part00178.country_merged.jsonl (2011 records)
# ✓ v3.1_oag_author.part00179.filtered.jsonl → v3.1_oag_author.part00179.country_merged.jsonl (6916 records)
# ✓ v3.1_oag_author.part00180.filtered.jsonl → v3.1_oag_author.part00180.country_merged.jsonl (4794 records)
# ✓ v3.1_oag_author.part00181.filtered.jsonl → v3.1_oag_author.part00181.country_merged.jsonl (2572 records)
# ✓ v3.1_oag_author.part00182.filtered.jsonl → v3.1_oag_author.part00182.country_merged.jsonl (5097 records)
# ✓ v3.1_oag_author.part00183.filtered.jsonl → v3.1_oag_author.part00183.country_merged.jsonl (6331 records)
# ✓ v3.1_oag_author.part00184.filtered.jsonl → v3.1_oag_author.part00184.country_merged.jsonl (3824 records)
# ✓ v3.1_oag_author.part00185.filtered.jsonl → v3.1_oag_author.part00185.country_merged.jsonl (1168 records)
# ✓ v3.1_oag_author.part00186.filtered.jsonl → v3.1_oag_author.part00186.country_merged.jsonl (7323 records)
# ✓ v3.1_oag_author.part00187.filtered.jsonl → v3.1_oag_author.part00187.country_merged.jsonl (4871 records)
# ✓ v3.1_oag_author.part00188.filtered.jsonl → v3.1_oag_author.part00188.country_merged.jsonl (3042 records)
# ✓ v3.1_oag_author.part00189.filtered.jsonl → v3.1_oag_author.part00189.country_merged.jsonl (3947 records)
# ✓ v3.1_oag_author.part00190.filtered.jsonl → v3.1_oag_author.part00190.country_merged.jsonl (6894 records)
# ✓ v3.1_oag_author.part00191.filtered.jsonl → v3.1_oag_author.part00191.country_merged.jsonl (4002 records)
# ✓ v3.1_oag_author.part00192.filtered.jsonl → v3.1_oag_author.part00192.country_merged.jsonl (1451 records)
# ✓ v3.1_oag_author.part00193.filtered.jsonl → v3.1_oag_author.part00193.country_merged.jsonl (6838 records)
# ✓ v3.1_oag_author.part00194.filtered.jsonl → v3.1_oag_author.part00194.country_merged.jsonl (5197 records)
# ✓ v3.1_oag_author.part00195.filtered.jsonl → v3.1_oag_author.part00195.country_merged.jsonl (3601 records)
# ✓ v3.1_oag_author.part00196.filtered.jsonl → v3.1_oag_author.part00196.country_merged.jsonl (2920 records)
# ✓ v3.1_oag_author.part00197.filtered.jsonl → v3.1_oag_author.part00197.country_merged.jsonl (6839 records)
# ✓ v3.1_oag_author.part00198.filtered.jsonl → v3.1_oag_author.part00198.country_merged.jsonl (4223 records)
# ✓ v3.1_oag_author.part00199.filtered.jsonl → v3.1_oag_author.part00199.country_merged.jsonl (1993 records)
# ✓ v3.1_oag_author.part00200.filtered.jsonl → v3.1_oag_author.part00200.country_merged.jsonl (6026 records)
# ✓ v3.1_oag_author.part00201.filtered.jsonl → v3.1_oag_author.part00201.country_merged.jsonl (5862 records)
# ✓ v3.1_oag_author.part00202.filtered.jsonl → v3.1_oag_author.part00202.country_merged.jsonl (3496 records)
# ✓ v3.1_oag_author.part00203.filtered.jsonl → v3.1_oag_author.part00203.country_merged.jsonl (2087 records)
# ✓ v3.1_oag_author.part00204.filtered.jsonl → v3.1_oag_author.part00204.country_merged.jsonl (6920 records)
# ✓ v3.1_oag_author.part00205.filtered.jsonl → v3.1_oag_author.part00205.country_merged.jsonl (4763 records)
# ✓ v3.1_oag_author.part00206.filtered.jsonl → v3.1_oag_author.part00206.country_merged.jsonl (2662 records)
# ✓ v3.1_oag_author.part00207.filtered.jsonl → v3.1_oag_author.part00207.country_merged.jsonl (4950 records)
# ✓ v3.1_oag_author.part00208.filtered.jsonl → v3.1_oag_author.part00208.country_merged.jsonl (6529 records)
# ✓ v3.1_oag_author.part00209.filtered.jsonl → v3.1_oag_author.part00209.country_merged.jsonl (3943 records)
# ✓ v3.1_oag_author.part00210.filtered.jsonl → v3.1_oag_author.part00210.country_merged.jsonl (1089 records)
# ✓ v3.1_oag_author.part00211.filtered.jsonl → v3.1_oag_author.part00211.country_merged.jsonl (7374 records)
# ✓ v3.1_oag_author.part00212.filtered.jsonl → v3.1_oag_author.part00212.country_merged.jsonl (5027 records)
# ✓ v3.1_oag_author.part00213.filtered.jsonl → v3.1_oag_author.part00213.country_merged.jsonl (3035 records)
# ✓ v3.1_oag_author.part00214.filtered.jsonl → v3.1_oag_author.part00214.country_merged.jsonl (3735 records)
# ✓ v3.1_oag_author.part00215.filtered.jsonl → v3.1_oag_author.part00215.country_merged.jsonl (6927 records)
# ✓ v3.1_oag_author.part00216.filtered.jsonl → v3.1_oag_author.part00216.country_merged.jsonl (4017 records)
# ✓ v3.1_oag_author.part00217.filtered.jsonl → v3.1_oag_author.part00217.country_merged.jsonl (1578 records)
# ✓ v3.1_oag_author.part00218.filtered.jsonl → v3.1_oag_author.part00218.country_merged.jsonl (6924 records)
# ✓ v3.1_oag_author.part00219.filtered.jsonl → v3.1_oag_author.part00219.country_merged.jsonl (5312 records)
# ✓ v3.1_oag_author.part00220.filtered.jsonl → v3.1_oag_author.part00220.country_merged.jsonl (3574 records)
# ✓ v3.1_oag_author.part00221.filtered.jsonl → v3.1_oag_author.part00221.country_merged.jsonl (2817 records)
# ✓ v3.1_oag_author.part00222.filtered.jsonl → v3.1_oag_author.part00222.country_merged.jsonl (6834 records)
# ✓ v3.1_oag_author.part00223.filtered.jsonl → v3.1_oag_author.part00223.country_merged.jsonl (4255 records)
# ✓ v3.1_oag_author.part00224.filtered.jsonl → v3.1_oag_author.part00224.country_merged.jsonl (2058 records)
# ✓ v3.1_oag_author.part00225.filtered.jsonl → v3.1_oag_author.part00225.country_merged.jsonl (5918 records)
# ✓ v3.1_oag_author.part00226.filtered.jsonl → v3.1_oag_author.part00226.country_merged.jsonl (6156 records)
# ✓ v3.1_oag_author.part00227.filtered.jsonl → v3.1_oag_author.part00227.country_merged.jsonl (3568 records)
# ✓ v3.1_oag_author.part00228.filtered.jsonl → v3.1_oag_author.part00228.country_merged.jsonl (1775 records)
# ✓ v3.1_oag_author.part00229.filtered.jsonl → v3.1_oag_author.part00229.country_merged.jsonl (7026 records)
# ✓ v3.1_oag_author.part00230.filtered.jsonl → v3.1_oag_author.part00230.country_merged.jsonl (4874 records)
# ✓ v3.1_oag_author.part00231.filtered.jsonl → v3.1_oag_author.part00231.country_merged.jsonl (2678 records)
# ✓ v3.1_oag_author.part00232.filtered.jsonl → v3.1_oag_author.part00232.country_merged.jsonl (4642 records)
# ✓ v3.1_oag_author.part00233.filtered.jsonl → v3.1_oag_author.part00233.country_merged.jsonl (6710 records)
# ✓ v3.1_oag_author.part00234.filtered.jsonl → v3.1_oag_author.part00234.country_merged.jsonl (3642 records)
# ✓ v3.1_oag_author.part00235.filtered.jsonl → v3.1_oag_author.part00235.country_merged.jsonl (1266 records)
# ✓ v3.1_oag_author.part00236.filtered.jsonl → v3.1_oag_author.part00236.country_merged.jsonl (6934 records)
# ✓ v3.1_oag_author.part00237.filtered.jsonl → v3.1_oag_author.part00237.country_merged.jsonl (4778 records)
# ✓ v3.1_oag_author.part00238.filtered.jsonl → v3.1_oag_author.part00238.country_merged.jsonl (3567 records)
# ✓ v3.1_oag_author.part00239.filtered.jsonl → v3.1_oag_author.part00239.country_merged.jsonl (3327 records)
# ✓ v3.1_oag_author.part00240.filtered.jsonl → v3.1_oag_author.part00240.country_merged.jsonl (7027 records)
# ✓ v3.1_oag_author.part00241.filtered.jsonl → v3.1_oag_author.part00241.country_merged.jsonl (4083 records)
# ✓ v3.1_oag_author.part00242.filtered.jsonl → v3.1_oag_author.part00242.country_merged.jsonl (1830 records)
# ✓ v3.1_oag_author.part00243.filtered.jsonl → v3.1_oag_author.part00243.country_merged.jsonl (6363 records)
# ✓ v3.1_oag_author.part00244.filtered.jsonl → v3.1_oag_author.part00244.country_merged.jsonl (5785 records)
# ✓ v3.1_oag_author.part00245.filtered.jsonl → v3.1_oag_author.part00245.country_merged.jsonl (3496 records)
# ✓ v3.1_oag_author.part00246.filtered.jsonl → v3.1_oag_author.part00246.country_merged.jsonl (2389 records)
# ✓ v3.1_oag_author.part00247.filtered.jsonl → v3.1_oag_author.part00247.country_merged.jsonl (6922 records)
# ✓ v3.1_oag_author.part00248.filtered.jsonl → v3.1_oag_author.part00248.country_merged.jsonl (4772 records)
# ✓ v3.1_oag_author.part00249.filtered.jsonl → v3.1_oag_author.part00249.country_merged.jsonl (2615 records)
# ✓ v3.1_oag_author.part00250.filtered.jsonl → v3.1_oag_author.part00250.country_merged.jsonl (5212 records)
# ✓ v3.1_oag_author.part00251.filtered.jsonl → v3.1_oag_author.part00251.country_merged.jsonl (6481 records)
# ✓ v3.1_oag_author.part00252.filtered.jsonl → v3.1_oag_author.part00252.country_merged.jsonl (3779 records)
# ✓ v3.1_oag_author.part00253.filtered.jsonl → v3.1_oag_author.part00253.country_merged.jsonl (1261 records)
# ✓ v3.1_oag_author.part00254.filtered.jsonl → v3.1_oag_author.part00254.country_merged.jsonl (7153 records)
# ✓ v3.1_oag_author.part00255.filtered.jsonl → v3.1_oag_author.part00255.country_merged.jsonl (4954 records)
# ✓ v3.1_oag_author.part00256.filtered.jsonl → v3.1_oag_author.part00256.country_merged.jsonl (2977 records)
# ✓ v3.1_oag_author.part00257.filtered.jsonl → v3.1_oag_author.part00257.country_merged.jsonl (3963 records)
# ✓ v3.1_oag_author.part00258.filtered.jsonl → v3.1_oag_author.part00258.country_merged.jsonl (6816 records)
# ✓ v3.1_oag_author.part00259.filtered.jsonl → v3.1_oag_author.part00259.country_merged.jsonl (3951 records)
# ✓ v3.1_oag_author.part00260.filtered.jsonl → v3.1_oag_author.part00260.country_merged.jsonl (1539 records)
# ✓ v3.1_oag_author.part00261.filtered.jsonl → v3.1_oag_author.part00261.country_merged.jsonl (6784 records)
# ✓ v3.1_oag_author.part00262.filtered.jsonl → v3.1_oag_author.part00262.country_merged.jsonl (5111 records)
# ✓ v3.1_oag_author.part00263.filtered.jsonl → v3.1_oag_author.part00263.country_merged.jsonl (3608 records)
# ✓ v3.1_oag_author.part00264.filtered.jsonl → v3.1_oag_author.part00264.country_merged.jsonl (2915 records)
# ✓ v3.1_oag_author.part00265.filtered.jsonl → v3.1_oag_author.part00265.country_merged.jsonl (6881 records)
# ✓ v3.1_oag_author.part00266.filtered.jsonl → v3.1_oag_author.part00266.country_merged.jsonl (4293 records)
# ✓ v3.1_oag_author.part00267.filtered.jsonl → v3.1_oag_author.part00267.country_merged.jsonl (2053 records)
# ✓ v3.1_oag_author.part00268.filtered.jsonl → v3.1_oag_author.part00268.country_merged.jsonl (6173 records)
# ✓ v3.1_oag_author.part00269.filtered.jsonl → v3.1_oag_author.part00269.country_merged.jsonl (6019 records)
# ✓ v3.1_oag_author.part00270.filtered.jsonl → v3.1_oag_author.part00270.country_merged.jsonl (3566 records)
# ✓ v3.1_oag_author.part00271.filtered.jsonl → v3.1_oag_author.part00271.country_merged.jsonl (2001 records)
# ✓ v3.1_oag_author.part00272.filtered.jsonl → v3.1_oag_author.part00272.country_merged.jsonl (6883 records)
# ✓ v3.1_oag_author.part00273.filtered.jsonl → v3.1_oag_author.part00273.country_merged.jsonl (4794 records)
# ✓ v3.1_oag_author.part00274.filtered.jsonl → v3.1_oag_author.part00274.country_merged.jsonl (2596 records)
# ✓ v3.1_oag_author.part00275.filtered.jsonl → v3.1_oag_author.part00275.country_merged.jsonl (5320 records)
# ✓ v3.1_oag_author.part00276.filtered.jsonl → v3.1_oag_author.part00276.country_merged.jsonl (6629 records)
# ✓ v3.1_oag_author.part00277.filtered.jsonl → v3.1_oag_author.part00277.country_merged.jsonl (3855 records)
# ✓ v3.1_oag_author.part00278.filtered.jsonl → v3.1_oag_author.part00278.country_merged.jsonl (1064 records)
# ✓ v3.1_oag_author.part00279.filtered.jsonl → v3.1_oag_author.part00279.country_merged.jsonl (7213 records)
# ✓ v3.1_oag_author.part00280.filtered.jsonl → v3.1_oag_author.part00280.country_merged.jsonl (5250 records)
# ✓ v3.1_oag_author.part00281.filtered.jsonl → v3.1_oag_author.part00281.country_merged.jsonl (2412 records)
# ✓ v3.1_oag_author.part00282.filtered.jsonl → v3.1_oag_author.part00282.country_merged.jsonl (3682 records)
# ✓ v3.1_oag_author.part00283.filtered.jsonl → v3.1_oag_author.part00283.country_merged.jsonl (6530 records)
# ✓ v3.1_oag_author.part00284.filtered.jsonl → v3.1_oag_author.part00284.country_merged.jsonl (4101 records)
# ✓ v3.1_oag_author.part00285.filtered.jsonl → v3.1_oag_author.part00285.country_merged.jsonl (573 records)
# ✓ v3.1_oag_author.part00286.filtered.jsonl → v3.1_oag_author.part00286.country_merged.jsonl (6864 records)
# ✓ v3.1_oag_author.part00287.filtered.jsonl → v3.1_oag_author.part00287.country_merged.jsonl (5334 records)
# ✓ v3.1_oag_author.part00288.filtered.jsonl → v3.1_oag_author.part00288.country_merged.jsonl (3061 records)
# ✓ v3.1_oag_author.part00289.filtered.jsonl → v3.1_oag_author.part00289.country_merged.jsonl (2528 records)
# ✓ v3.1_oag_author.part00290.filtered.jsonl → v3.1_oag_author.part00290.country_merged.jsonl (6820 records)
# ✓ v3.1_oag_author.part00291.filtered.jsonl → v3.1_oag_author.part00291.country_merged.jsonl (4632 records)
# ✓ v3.1_oag_author.part00292.filtered.jsonl → v3.1_oag_author.part00292.country_merged.jsonl (1321 records)
# ✓ v3.1_oag_author.part00293.filtered.jsonl → v3.1_oag_author.part00293.country_merged.jsonl (5908 records)
# ✓ v3.1_oag_author.part00294.filtered.jsonl → v3.1_oag_author.part00294.country_merged.jsonl (6084 records)
# ✓ v3.1_oag_author.part00295.filtered.jsonl → v3.1_oag_author.part00295.country_merged.jsonl (3301 records)
# ✓ v3.1_oag_author.part00296.filtered.jsonl → v3.1_oag_author.part00296.country_merged.jsonl (1377 records)
# ✓ v3.1_oag_author.part00297.filtered.jsonl → v3.1_oag_author.part00297.country_merged.jsonl (6561 records)
# ✓ v3.1_oag_author.part00298.filtered.jsonl → v3.1_oag_author.part00298.country_merged.jsonl (5070 records)
# ✓ v3.1_oag_author.part00299.filtered.jsonl → v3.1_oag_author.part00299.country_merged.jsonl (2025 records)
# ✓ v3.1_oag_author.part00300.filtered.jsonl → v3.1_oag_author.part00300.country_merged.jsonl (4696 records)
#
# ✅ Done. Processed 1,342,203 records, wrote 1,342,203 records.

# %%
import pandas as pd

df = pd.DataFrame(
    [(k, v, v / sum(merged_counter.values()) * 100) for k, v in merged_counter.items()],
    columns=["country", "count", "percent"]
).sort_values("count", ascending=False)

out_csv = OUTPUT_DIR / "country_distribution_merged_lowercase.csv"
df.to_csv(out_csv, index=False, encoding="utf-8-sig")

print(f"Saved lowercase merged distribution → {out_csv}")
# Out:
# Saved lowercase merged distribution → C:\Users\XxRui\Desktop\newData\output\country_merged_batches\country_distribution_merged_lowercase.csv
