# %%
# === Config ===
from pathlib import Path
import re, json, sys

# Set your input directory (folder containing v3.1_oag_author.part00000.jsonl ... part00357.jsonl)
INPUT_DIR = Path(r"C:\Users\XxRui\Desktop\newData\oag_chunks")  # <-- change me
# Output directory (will be created). If you prefer "alongside", set OUTPUT_DIR = INPUT_DIR
OUTPUT_DIR = Path(r"C:\Users\XxRui\Desktop\newData\output") 
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# === Build country lexicon ===
def build_country_set():
    base = set()

    # Fallback: built-in list (covers most occurrences in OAG org strings)
    fallback = {
        # Common English names
        "china","japan","france","germany","spain","italy","portugal","mexico","canada","australia",
        "new zealand","united kingdom","netherlands","sweden","norway","denmark","finland","iceland",
        "ireland","poland","czech republic","slovakia","hungary","slovenia","croatia","serbia",
        "romania","bulgaria","greece","turkey","israel","egypt","south africa","nigeria","kenya",
        "russia","russian federation","ukraine","belarus","kazakhstan","uzbekistan",
        "india","bangladesh","pakistan","sri lanka","nepal","bhutan",
        "thailand","vietnam","laos","cambodia","myanmar","philippines","malaysia","singapore",
        "indonesia","brunei","taiwan","republic of china","r.o.c.","roc",
        "south korea","republic of korea","korea","north korea",
        "saudi arabia","united arab emirates","uae","qatar","kuwait","oman","bahrain","iran","iraq","jordan","lebanon",
        "brazil","argentina","chile","peru","colombia","venezuela","uruguay","paraguay","bolivia","ecuador",
        "switzerland","austria","belgium","luxembourg","liechtenstein","monaco","andorra","malta","cyprus",
        # English variants frequently seen
        "united states","united states of america","usa","u.s.a.","u.s.","u.s.a","u.s",
        "PRC","ROC",
        "uk","u.k.","the netherlands","the bahamas","côte d’ivoire","cote d’ivoire","ivory coast",
        "the gambia","dominican republic","costa rica","el salvador","guatemala","honduras","nicaragua","panama",
        # Native language endonyms commonly appearing in org lines
        "deutschland","españa","méxico","brasil","rossiyskaya federatsiya","российская федерация",
        "suomi","norge","danmark","polska","magyarország","italia","sverige","schweiz","österreich","elláda","ελλάδα",
        "대한민국","日本","中国","россия","台灣","臺灣","香港","澳门","澳門",
        # UK component nations sometimes used informally
        "england","scotland","wales","northern ireland"
    }
    base |= {c.lower() for c in fallback}

    # Try to add canonical names from pycountry if available
    try:
        import pycountry
        for c in pycountry.countries:
            base.add(c.name.lower())
            if hasattr(c, "official_name"):
                base.add(c.official_name.lower())
            for alpha in ("alpha_2","alpha_3"):
                if getattr(c, alpha, None):
                    base.add(getattr(c, alpha).lower())
        # Common historical/short forms not always in pycountry
        base |= {"uk","u.k.","usa","u.s.a.","u.s."}
    except Exception:
        pass

    # normalize spacing for matching
    return {re.sub(r"\s+", " ", x.strip()) for x in base}

COUNTRIES = build_country_set()

# === Compile a regex to capture `, Country` pattern robustly
# We will:
#  1) normalize org whitespace (collapse spaces)
#  2) search for comma (allow optional spaces around), then a country token
#  3) accept matches before end, semicolon, period, parenthesis, or EOL
COMMA_COUNTRY_RE = re.compile(r",\s*([A-Za-z\.\u00C0-\u024F\u0370-\u03FF\u0400-\u04FF\u3040-\u30FF\u4E00-\u9FFF][^;()\[\]]{0,60})")

def normalize_text(s: str) -> str:
    # collapse multiple spaces, remove stray NBSPs
    return re.sub(r"\s+", " ", (s or "").replace("\xa0"," ")).strip()

def extract_comma_country(org: str):
    """
    Returns (True, matched_country) if org has a ', Country' style segment
    where 'Country' matches our country lexicon (case-insensitive),
    after basic normalization. Otherwise returns (False, None).
    """
    if not org:
        return (False, None)

    org_norm = normalize_text(org)
    for m in COMMA_COUNTRY_RE.finditer(org_norm):
        raw_tail = m.group(1).strip()
        # stop at typical terminators
        raw_tail = re.split(r"[.;,)]+", raw_tail)[0].strip()

        # try single or first 1-3 tokens (to catch things like 'Republic of Korea', 'United States',
        # and also variants like 'U.S.A.' and 'U.K.')
        candidates = set()

        # exact tail
        candidates.add(raw_tail.lower())

        # progressively shorten to first k tokens (k up to 4)
        toks = raw_tail.split()
        for k in range(1, min(4, len(toks)) + 1):
            candidates.add(" ".join(toks[:k]).lower())

        # punctuation-stripped variants (e.g., 'U.S.A.' -> 'usa')
        punct_free = re.sub(r"[^\w\s]","", raw_tail).lower()
        if punct_free:
            candidates.add(punct_free)
            toks2 = punct_free.split()
            for k in range(1, min(4, len(toks2)) + 1):
                candidates.add(" ".join(toks2[:k]).lower())

        # final check against lexicon
        for cand in candidates:
            cand_norm = re.sub(r"\s+", " ", cand).strip()
            if cand_norm in COUNTRIES:
                return (True, cand_norm)

    return (False, None)

# === Stream filter ===
def iter_jsonl(path: Path):
    with path.open("r", encoding="utf-8", errors="ignore") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                yield json.loads(line)
            except Exception:
                # Skip malformed line
                continue

def output_name_for(input_path: Path) -> Path:
    # v3.1_oag_author.part00000.jsonl -> v3.1_oag_author.part00000.filtered.jsonl
    return OUTPUT_DIR / (input_path.stem + ".filtered.jsonl")

def filter_batch_file(in_path: Path) -> dict:
    keep = 0
    total = 0
    out_path = output_name_for(in_path)
    with out_path.open("w", encoding="utf-8") as out_f:
        for obj in iter_jsonl(in_path):
            total += 1
            id_  = obj.get("id")
            name = obj.get("name")
            org  = obj.get("org")

            # Must have required keys
            if not (id_ and name and org):
                continue

            has_country, _ = extract_comma_country(org)
            if has_country:
                keep += 1
                # Emit only the required fields in normalized form
                record = {
                    "id": str(id_),
                    "name": normalize_text(name),
                    "org": normalize_text(org),
                }
                out_f.write(json.dumps(record, ensure_ascii=False) + "\n")

    return {"file": in_path.name, "kept": keep, "total": total, "out": out_path.name}

# === Run over all parts ===
parts = sorted(INPUT_DIR.glob("v3.1_oag_author.part*.jsonl"))
if not parts:
    print(f"⚠️ No files matched in {INPUT_DIR}")
else:
    summary = []
    for p in parts:
        stats = filter_batch_file(p)
        summary.append(stats)
        print(f"✓ {stats['file']}: kept {stats['kept']}/{stats['total']} → {stats['out']}")

    kept_sum = sum(s["kept"] for s in summary)
    total_sum = sum(s["total"] for s in summary)
    print("\n==== Done ====")
    print(f"Total kept: {kept_sum} / {total_sum} ({(kept_sum/total_sum*100 if total_sum else 0):.2f}%)")
    print(f"Output dir: {OUTPUT_DIR}")

# %%
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd

COUNTER = Counter()  # to collect country frequencies globally

def extract_countries(org: str):
    """Return list of all distinct matched country names (normalized)"""
    if not org:
        return []
    org_norm = normalize_text(org)
    matches = []
    for m in COMMA_COUNTRY_RE.finditer(org_norm):
        raw_tail = m.group(1).strip()
        raw_tail = re.split(r"[.;,)]+", raw_tail)[0].strip()

        toks = raw_tail.split()
        # try combos up to 4 tokens
        candidates = {raw_tail.lower()}
        for k in range(1, min(4, len(toks)) + 1):
            candidates.add(" ".join(toks[:k]).lower())
        punct_free = re.sub(r"[^\w\s]", "", raw_tail).lower()
        if punct_free:
            candidates.add(punct_free)
            toks2 = punct_free.split()
            for k in range(1, min(4, len(toks2)) + 1):
                candidates.add(" ".join(toks2[:k]).lower())

        for cand in candidates:
            cand_norm = re.sub(r"\s+", " ", cand.strip())
            if cand_norm in COUNTRIES:
                matches.append(cand_norm)
                break
    # unique normalized list
    return sorted(set(matches))

def filter_batch_file_with_country(in_path: Path) -> dict:
    keep = 0
    total = 0
    out_path = output_name_for(in_path)
    with out_path.open("w", encoding="utf-8") as out_f:
        for obj in iter_jsonl(in_path):
            total += 1
            id_  = obj.get("id")
            name = obj.get("name")
            org  = obj.get("org")
            if not (id_ and name and org):
                continue

            countries = extract_countries(org)
            if len(countries) == 1:
                country = countries[0]
                keep += 1
                COUNTER[country] += 1
                record = {
                    "id": str(id_),
                    "name": normalize_text(name),
                    "org": normalize_text(org),
                    "country": country,
                }
                out_f.write(json.dumps(record, ensure_ascii=False) + "\n")

    return {"file": in_path.name, "kept": keep, "total": total, "out": out_path.name}

# === Run across all parts ===
parts = sorted(INPUT_DIR.glob("v3.1_oag_author.part*.jsonl"))
summary = []
for p in parts:
    stats = filter_batch_file_with_country(p)
    summary.append(stats)
    print(f"✓ {stats['file']}: kept {stats['kept']}/{stats['total']} → {stats['out']}")

kept_sum = sum(s["kept"] for s in summary)
total_sum = sum(s["total"] for s in summary)
print("\n==== Done ====")
print(f"Total kept: {kept_sum} / {total_sum} ({(kept_sum/total_sum*100 if total_sum else 0):.2f}%)")
# Out:
# ✓ v3.1_oag_author.part00000.jsonl: kept 7296/100000 → v3.1_oag_author.part00000.filtered.jsonl
# ✓ v3.1_oag_author.part00001.jsonl: kept 4951/100000 → v3.1_oag_author.part00001.filtered.jsonl
# ✓ v3.1_oag_author.part00002.jsonl: kept 3098/100000 → v3.1_oag_author.part00002.filtered.jsonl
# ✓ v3.1_oag_author.part00003.jsonl: kept 3922/100000 → v3.1_oag_author.part00003.filtered.jsonl
# ✓ v3.1_oag_author.part00004.jsonl: kept 6736/100000 → v3.1_oag_author.part00004.filtered.jsonl
# ✓ v3.1_oag_author.part00005.jsonl: kept 3924/100000 → v3.1_oag_author.part00005.filtered.jsonl
# ✓ v3.1_oag_author.part00006.jsonl: kept 1538/100000 → v3.1_oag_author.part00006.filtered.jsonl
# ✓ v3.1_oag_author.part00007.jsonl: kept 6689/100000 → v3.1_oag_author.part00007.filtered.jsonl
# ✓ v3.1_oag_author.part00008.jsonl: kept 5295/100000 → v3.1_oag_author.part00008.filtered.jsonl
# ✓ v3.1_oag_author.part00009.jsonl: kept 3689/100000 → v3.1_oag_author.part00009.filtered.jsonl
# ✓ v3.1_oag_author.part00010.jsonl: kept 2809/100000 → v3.1_oag_author.part00010.filtered.jsonl
# ✓ v3.1_oag_author.part00011.jsonl: kept 7000/100000 → v3.1_oag_author.part00011.filtered.jsonl
# ✓ v3.1_oag_author.part00012.jsonl: kept 4351/100000 → v3.1_oag_author.part00012.filtered.jsonl
# ✓ v3.1_oag_author.part00013.jsonl: kept 1983/100000 → v3.1_oag_author.part00013.filtered.jsonl
# ✓ v3.1_oag_author.part00014.jsonl: kept 6085/100000 → v3.1_oag_author.part00014.filtered.jsonl
# ✓ v3.1_oag_author.part00015.jsonl: kept 5843/100000 → v3.1_oag_author.part00015.filtered.jsonl
# ✓ v3.1_oag_author.part00016.jsonl: kept 3594/100000 → v3.1_oag_author.part00016.filtered.jsonl
# ✓ v3.1_oag_author.part00017.jsonl: kept 2078/100000 → v3.1_oag_author.part00017.filtered.jsonl
# ✓ v3.1_oag_author.part00018.jsonl: kept 5602/100000 → v3.1_oag_author.part00018.filtered.jsonl
# ✓ v3.1_oag_author.part00019.jsonl: kept 4090/100000 → v3.1_oag_author.part00019.filtered.jsonl
# ✓ v3.1_oag_author.part00020.jsonl: kept 4793/100000 → v3.1_oag_author.part00020.filtered.jsonl
# ✓ v3.1_oag_author.part00021.jsonl: kept 4557/100000 → v3.1_oag_author.part00021.filtered.jsonl
# ✓ v3.1_oag_author.part00022.jsonl: kept 3803/100000 → v3.1_oag_author.part00022.filtered.jsonl
# ✓ v3.1_oag_author.part00023.jsonl: kept 5700/100000 → v3.1_oag_author.part00023.filtered.jsonl
# ✓ v3.1_oag_author.part00024.jsonl: kept 2507/100000 → v3.1_oag_author.part00024.filtered.jsonl
# ✓ v3.1_oag_author.part00025.jsonl: kept 6066/100000 → v3.1_oag_author.part00025.filtered.jsonl
# ✓ v3.1_oag_author.part00026.jsonl: kept 3517/100000 → v3.1_oag_author.part00026.filtered.jsonl
# ✓ v3.1_oag_author.part00027.jsonl: kept 5573/100000 → v3.1_oag_author.part00027.filtered.jsonl
# ✓ v3.1_oag_author.part00028.jsonl: kept 4036/100000 → v3.1_oag_author.part00028.filtered.jsonl
# ✓ v3.1_oag_author.part00029.jsonl: kept 4444/100000 → v3.1_oag_author.part00029.filtered.jsonl
# ✓ v3.1_oag_author.part00030.jsonl: kept 4670/100000 → v3.1_oag_author.part00030.filtered.jsonl
# ✓ v3.1_oag_author.part00031.jsonl: kept 3474/100000 → v3.1_oag_author.part00031.filtered.jsonl
# ✓ v3.1_oag_author.part00032.jsonl: kept 6522/100000 → v3.1_oag_author.part00032.filtered.jsonl
# ✓ v3.1_oag_author.part00033.jsonl: kept 5323/100000 → v3.1_oag_author.part00033.filtered.jsonl
# ✓ v3.1_oag_author.part00034.jsonl: kept 3598/100000 → v3.1_oag_author.part00034.filtered.jsonl
# ✓ v3.1_oag_author.part00035.jsonl: kept 2729/100000 → v3.1_oag_author.part00035.filtered.jsonl
# ✓ v3.1_oag_author.part00036.jsonl: kept 6975/100000 → v3.1_oag_author.part00036.filtered.jsonl
# ✓ v3.1_oag_author.part00037.jsonl: kept 4465/100000 → v3.1_oag_author.part00037.filtered.jsonl
# ✓ v3.1_oag_author.part00038.jsonl: kept 2204/100000 → v3.1_oag_author.part00038.filtered.jsonl
# ✓ v3.1_oag_author.part00039.jsonl: kept 5861/100000 → v3.1_oag_author.part00039.filtered.jsonl
# ✓ v3.1_oag_author.part00040.jsonl: kept 5984/100000 → v3.1_oag_author.part00040.filtered.jsonl
# ✓ v3.1_oag_author.part00041.jsonl: kept 3579/100000 → v3.1_oag_author.part00041.filtered.jsonl
# ✓ v3.1_oag_author.part00042.jsonl: kept 1793/100000 → v3.1_oag_author.part00042.filtered.jsonl
# ✓ v3.1_oag_author.part00043.jsonl: kept 7019/100000 → v3.1_oag_author.part00043.filtered.jsonl
# ✓ v3.1_oag_author.part00044.jsonl: kept 4711/100000 → v3.1_oag_author.part00044.filtered.jsonl
# ✓ v3.1_oag_author.part00045.jsonl: kept 2797/100000 → v3.1_oag_author.part00045.filtered.jsonl
# ✓ v3.1_oag_author.part00046.jsonl: kept 4605/100000 → v3.1_oag_author.part00046.filtered.jsonl
# ✓ v3.1_oag_author.part00047.jsonl: kept 6849/100000 → v3.1_oag_author.part00047.filtered.jsonl
# ✓ v3.1_oag_author.part00048.jsonl: kept 3803/100000 → v3.1_oag_author.part00048.filtered.jsonl
# ✓ v3.1_oag_author.part00049.jsonl: kept 1152/100000 → v3.1_oag_author.part00049.filtered.jsonl
# ✓ v3.1_oag_author.part00050.jsonl: kept 7082/100000 → v3.1_oag_author.part00050.filtered.jsonl
# ✓ v3.1_oag_author.part00051.jsonl: kept 4881/100000 → v3.1_oag_author.part00051.filtered.jsonl
# ✓ v3.1_oag_author.part00052.jsonl: kept 3462/100000 → v3.1_oag_author.part00052.filtered.jsonl
# ✓ v3.1_oag_author.part00053.jsonl: kept 3514/100000 → v3.1_oag_author.part00053.filtered.jsonl
# ✓ v3.1_oag_author.part00054.jsonl: kept 6932/100000 → v3.1_oag_author.part00054.filtered.jsonl
# ✓ v3.1_oag_author.part00055.jsonl: kept 3984/100000 → v3.1_oag_author.part00055.filtered.jsonl
# ✓ v3.1_oag_author.part00056.jsonl: kept 1750/100000 → v3.1_oag_author.part00056.filtered.jsonl
# ✓ v3.1_oag_author.part00057.jsonl: kept 6317/100000 → v3.1_oag_author.part00057.filtered.jsonl
# ✓ v3.1_oag_author.part00058.jsonl: kept 5613/100000 → v3.1_oag_author.part00058.filtered.jsonl
# ✓ v3.1_oag_author.part00059.jsonl: kept 3436/100000 → v3.1_oag_author.part00059.filtered.jsonl
# ✓ v3.1_oag_author.part00060.jsonl: kept 2456/100000 → v3.1_oag_author.part00060.filtered.jsonl
# ✓ v3.1_oag_author.part00061.jsonl: kept 6721/100000 → v3.1_oag_author.part00061.filtered.jsonl
# ✓ v3.1_oag_author.part00062.jsonl: kept 4690/100000 → v3.1_oag_author.part00062.filtered.jsonl
# ✓ v3.1_oag_author.part00063.jsonl: kept 2365/100000 → v3.1_oag_author.part00063.filtered.jsonl
# ✓ v3.1_oag_author.part00064.jsonl: kept 5384/100000 → v3.1_oag_author.part00064.filtered.jsonl
# ✓ v3.1_oag_author.part00065.jsonl: kept 6321/100000 → v3.1_oag_author.part00065.filtered.jsonl
# ✓ v3.1_oag_author.part00066.jsonl: kept 3721/100000 → v3.1_oag_author.part00066.filtered.jsonl
# ✓ v3.1_oag_author.part00067.jsonl: kept 1465/100000 → v3.1_oag_author.part00067.filtered.jsonl
# ✓ v3.1_oag_author.part00068.jsonl: kept 7126/100000 → v3.1_oag_author.part00068.filtered.jsonl
# ✓ v3.1_oag_author.part00069.jsonl: kept 4888/100000 → v3.1_oag_author.part00069.filtered.jsonl
# ✓ v3.1_oag_author.part00070.jsonl: kept 2980/100000 → v3.1_oag_author.part00070.filtered.jsonl
# ✓ v3.1_oag_author.part00071.jsonl: kept 4183/100000 → v3.1_oag_author.part00071.filtered.jsonl
# ✓ v3.1_oag_author.part00072.jsonl: kept 6716/100000 → v3.1_oag_author.part00072.filtered.jsonl
# ✓ v3.1_oag_author.part00073.jsonl: kept 3993/100000 → v3.1_oag_author.part00073.filtered.jsonl
# ✓ v3.1_oag_author.part00074.jsonl: kept 1359/100000 → v3.1_oag_author.part00074.filtered.jsonl
# ✓ v3.1_oag_author.part00075.jsonl: kept 7102/100000 → v3.1_oag_author.part00075.filtered.jsonl
# ✓ v3.1_oag_author.part00076.jsonl: kept 5047/100000 → v3.1_oag_author.part00076.filtered.jsonl
# ✓ v3.1_oag_author.part00077.jsonl: kept 3646/100000 → v3.1_oag_author.part00077.filtered.jsonl
# ✓ v3.1_oag_author.part00078.jsonl: kept 2895/100000 → v3.1_oag_author.part00078.filtered.jsonl
# ✓ v3.1_oag_author.part00079.jsonl: kept 6809/100000 → v3.1_oag_author.part00079.filtered.jsonl
# ✓ v3.1_oag_author.part00080.jsonl: kept 4362/100000 → v3.1_oag_author.part00080.filtered.jsonl
# ✓ v3.1_oag_author.part00081.jsonl: kept 2033/100000 → v3.1_oag_author.part00081.filtered.jsonl
# ✓ v3.1_oag_author.part00082.jsonl: kept 6113/100000 → v3.1_oag_author.part00082.filtered.jsonl
# ✓ v3.1_oag_author.part00083.jsonl: kept 5951/100000 → v3.1_oag_author.part00083.filtered.jsonl
# ✓ v3.1_oag_author.part00084.jsonl: kept 3517/100000 → v3.1_oag_author.part00084.filtered.jsonl
# ✓ v3.1_oag_author.part00085.jsonl: kept 1990/100000 → v3.1_oag_author.part00085.filtered.jsonl
# ✓ v3.1_oag_author.part00086.jsonl: kept 6826/100000 → v3.1_oag_author.part00086.filtered.jsonl
# ✓ v3.1_oag_author.part00087.jsonl: kept 4896/100000 → v3.1_oag_author.part00087.filtered.jsonl
# ✓ v3.1_oag_author.part00088.jsonl: kept 2577/100000 → v3.1_oag_author.part00088.filtered.jsonl
# ✓ v3.1_oag_author.part00089.jsonl: kept 4914/100000 → v3.1_oag_author.part00089.filtered.jsonl
# ✓ v3.1_oag_author.part00090.jsonl: kept 6485/100000 → v3.1_oag_author.part00090.filtered.jsonl
# ✓ v3.1_oag_author.part00091.jsonl: kept 3728/100000 → v3.1_oag_author.part00091.filtered.jsonl
# ✓ v3.1_oag_author.part00092.jsonl: kept 1093/100000 → v3.1_oag_author.part00092.filtered.jsonl
# ✓ v3.1_oag_author.part00093.jsonl: kept 7218/100000 → v3.1_oag_author.part00093.filtered.jsonl
# ✓ v3.1_oag_author.part00094.jsonl: kept 4973/100000 → v3.1_oag_author.part00094.filtered.jsonl
# ✓ v3.1_oag_author.part00095.jsonl: kept 3136/100000 → v3.1_oag_author.part00095.filtered.jsonl
# ✓ v3.1_oag_author.part00096.jsonl: kept 3997/100000 → v3.1_oag_author.part00096.filtered.jsonl
# ✓ v3.1_oag_author.part00097.jsonl: kept 6855/100000 → v3.1_oag_author.part00097.filtered.jsonl
# ✓ v3.1_oag_author.part00098.jsonl: kept 3914/100000 → v3.1_oag_author.part00098.filtered.jsonl
# ✓ v3.1_oag_author.part00099.jsonl: kept 1575/100000 → v3.1_oag_author.part00099.filtered.jsonl
# ✓ v3.1_oag_author.part00100.jsonl: kept 6605/100000 → v3.1_oag_author.part00100.filtered.jsonl
# ✓ v3.1_oag_author.part00101.jsonl: kept 5282/100000 → v3.1_oag_author.part00101.filtered.jsonl
# ✓ v3.1_oag_author.part00102.jsonl: kept 3593/100000 → v3.1_oag_author.part00102.filtered.jsonl
# ✓ v3.1_oag_author.part00103.jsonl: kept 2863/100000 → v3.1_oag_author.part00103.filtered.jsonl
# ✓ v3.1_oag_author.part00104.jsonl: kept 6873/100000 → v3.1_oag_author.part00104.filtered.jsonl
# ✓ v3.1_oag_author.part00105.jsonl: kept 4352/100000 → v3.1_oag_author.part00105.filtered.jsonl
# ✓ v3.1_oag_author.part00106.jsonl: kept 2066/100000 → v3.1_oag_author.part00106.filtered.jsonl
# ✓ v3.1_oag_author.part00107.jsonl: kept 6116/100000 → v3.1_oag_author.part00107.filtered.jsonl
# ✓ v3.1_oag_author.part00108.jsonl: kept 6003/100000 → v3.1_oag_author.part00108.filtered.jsonl
# ✓ v3.1_oag_author.part00109.jsonl: kept 3600/100000 → v3.1_oag_author.part00109.filtered.jsonl
# ✓ v3.1_oag_author.part00110.jsonl: kept 1795/100000 → v3.1_oag_author.part00110.filtered.jsonl
# ✓ v3.1_oag_author.part00111.jsonl: kept 7128/100000 → v3.1_oag_author.part00111.filtered.jsonl
# ✓ v3.1_oag_author.part00112.jsonl: kept 4860/100000 → v3.1_oag_author.part00112.filtered.jsonl
# ✓ v3.1_oag_author.part00113.jsonl: kept 2678/100000 → v3.1_oag_author.part00113.filtered.jsonl
# ✓ v3.1_oag_author.part00114.jsonl: kept 4836/100000 → v3.1_oag_author.part00114.filtered.jsonl
# ✓ v3.1_oag_author.part00115.jsonl: kept 6634/100000 → v3.1_oag_author.part00115.filtered.jsonl
# ✓ v3.1_oag_author.part00116.jsonl: kept 3866/100000 → v3.1_oag_author.part00116.filtered.jsonl
# ✓ v3.1_oag_author.part00117.jsonl: kept 1191/100000 → v3.1_oag_author.part00117.filtered.jsonl
# ✓ v3.1_oag_author.part00118.jsonl: kept 7084/100000 → v3.1_oag_author.part00118.filtered.jsonl
# ✓ v3.1_oag_author.part00119.jsonl: kept 4966/100000 → v3.1_oag_author.part00119.filtered.jsonl
# ✓ v3.1_oag_author.part00120.jsonl: kept 3004/100000 → v3.1_oag_author.part00120.filtered.jsonl
# ✓ v3.1_oag_author.part00121.jsonl: kept 3798/100000 → v3.1_oag_author.part00121.filtered.jsonl
# ✓ v3.1_oag_author.part00122.jsonl: kept 6878/100000 → v3.1_oag_author.part00122.filtered.jsonl
# ✓ v3.1_oag_author.part00123.jsonl: kept 3945/100000 → v3.1_oag_author.part00123.filtered.jsonl
# ✓ v3.1_oag_author.part00124.jsonl: kept 1620/100000 → v3.1_oag_author.part00124.filtered.jsonl
# ✓ v3.1_oag_author.part00125.jsonl: kept 6636/100000 → v3.1_oag_author.part00125.filtered.jsonl
# ✓ v3.1_oag_author.part00126.jsonl: kept 5398/100000 → v3.1_oag_author.part00126.filtered.jsonl
# ✓ v3.1_oag_author.part00127.jsonl: kept 3601/100000 → v3.1_oag_author.part00127.filtered.jsonl
# ✓ v3.1_oag_author.part00128.jsonl: kept 2735/100000 → v3.1_oag_author.part00128.filtered.jsonl
# ✓ v3.1_oag_author.part00129.jsonl: kept 7005/100000 → v3.1_oag_author.part00129.filtered.jsonl
# ✓ v3.1_oag_author.part00130.jsonl: kept 4353/100000 → v3.1_oag_author.part00130.filtered.jsonl
# ✓ v3.1_oag_author.part00131.jsonl: kept 2167/100000 → v3.1_oag_author.part00131.filtered.jsonl
# ✓ v3.1_oag_author.part00132.jsonl: kept 5947/100000 → v3.1_oag_author.part00132.filtered.jsonl
# ✓ v3.1_oag_author.part00133.jsonl: kept 6057/100000 → v3.1_oag_author.part00133.filtered.jsonl
# ✓ v3.1_oag_author.part00134.jsonl: kept 3590/100000 → v3.1_oag_author.part00134.filtered.jsonl
# ✓ v3.1_oag_author.part00135.jsonl: kept 1804/100000 → v3.1_oag_author.part00135.filtered.jsonl
# ✓ v3.1_oag_author.part00136.jsonl: kept 6989/100000 → v3.1_oag_author.part00136.filtered.jsonl
# ✓ v3.1_oag_author.part00137.jsonl: kept 4991/100000 → v3.1_oag_author.part00137.filtered.jsonl
# ✓ v3.1_oag_author.part00138.jsonl: kept 2707/100000 → v3.1_oag_author.part00138.filtered.jsonl
# ✓ v3.1_oag_author.part00139.jsonl: kept 4710/100000 → v3.1_oag_author.part00139.filtered.jsonl
# ✓ v3.1_oag_author.part00140.jsonl: kept 6681/100000 → v3.1_oag_author.part00140.filtered.jsonl
# ✓ v3.1_oag_author.part00141.jsonl: kept 3760/100000 → v3.1_oag_author.part00141.filtered.jsonl
# ✓ v3.1_oag_author.part00142.jsonl: kept 1184/100000 → v3.1_oag_author.part00142.filtered.jsonl
# ✓ v3.1_oag_author.part00143.jsonl: kept 7335/100000 → v3.1_oag_author.part00143.filtered.jsonl
# ✓ v3.1_oag_author.part00144.jsonl: kept 4967/100000 → v3.1_oag_author.part00144.filtered.jsonl
# ✓ v3.1_oag_author.part00145.jsonl: kept 3379/100000 → v3.1_oag_author.part00145.filtered.jsonl
# ✓ v3.1_oag_author.part00146.jsonl: kept 3377/100000 → v3.1_oag_author.part00146.filtered.jsonl
# ✓ v3.1_oag_author.part00147.jsonl: kept 7085/100000 → v3.1_oag_author.part00147.filtered.jsonl
# ✓ v3.1_oag_author.part00148.jsonl: kept 4029/100000 → v3.1_oag_author.part00148.filtered.jsonl
# ✓ v3.1_oag_author.part00149.jsonl: kept 1725/100000 → v3.1_oag_author.part00149.filtered.jsonl
# ✓ v3.1_oag_author.part00150.jsonl: kept 6392/100000 → v3.1_oag_author.part00150.filtered.jsonl
# ✓ v3.1_oag_author.part00151.jsonl: kept 5701/100000 → v3.1_oag_author.part00151.filtered.jsonl
# ✓ v3.1_oag_author.part00152.jsonl: kept 3471/100000 → v3.1_oag_author.part00152.filtered.jsonl
# ✓ v3.1_oag_author.part00153.jsonl: kept 2412/100000 → v3.1_oag_author.part00153.filtered.jsonl
# ✓ v3.1_oag_author.part00154.jsonl: kept 6766/100000 → v3.1_oag_author.part00154.filtered.jsonl
# ✓ v3.1_oag_author.part00155.jsonl: kept 4694/100000 → v3.1_oag_author.part00155.filtered.jsonl
# ✓ v3.1_oag_author.part00156.jsonl: kept 2399/100000 → v3.1_oag_author.part00156.filtered.jsonl
# ✓ v3.1_oag_author.part00157.jsonl: kept 5476/100000 → v3.1_oag_author.part00157.filtered.jsonl
# ✓ v3.1_oag_author.part00158.jsonl: kept 6362/100000 → v3.1_oag_author.part00158.filtered.jsonl
# ✓ v3.1_oag_author.part00159.jsonl: kept 3744/100000 → v3.1_oag_author.part00159.filtered.jsonl
# ✓ v3.1_oag_author.part00160.jsonl: kept 1372/100000 → v3.1_oag_author.part00160.filtered.jsonl
# ✓ v3.1_oag_author.part00161.jsonl: kept 7255/100000 → v3.1_oag_author.part00161.filtered.jsonl
# ✓ v3.1_oag_author.part00162.jsonl: kept 4986/100000 → v3.1_oag_author.part00162.filtered.jsonl
# ✓ v3.1_oag_author.part00163.jsonl: kept 3005/100000 → v3.1_oag_author.part00163.filtered.jsonl
# ✓ v3.1_oag_author.part00164.jsonl: kept 4309/100000 → v3.1_oag_author.part00164.filtered.jsonl
# ✓ v3.1_oag_author.part00165.jsonl: kept 6721/100000 → v3.1_oag_author.part00165.filtered.jsonl
# ✓ v3.1_oag_author.part00166.jsonl: kept 3920/100000 → v3.1_oag_author.part00166.filtered.jsonl
# ✓ v3.1_oag_author.part00167.jsonl: kept 1448/100000 → v3.1_oag_author.part00167.filtered.jsonl
# ✓ v3.1_oag_author.part00168.jsonl: kept 6983/100000 → v3.1_oag_author.part00168.filtered.jsonl
# ✓ v3.1_oag_author.part00169.jsonl: kept 5201/100000 → v3.1_oag_author.part00169.filtered.jsonl
# ✓ v3.1_oag_author.part00170.jsonl: kept 3524/100000 → v3.1_oag_author.part00170.filtered.jsonl
# ✓ v3.1_oag_author.part00171.jsonl: kept 2944/100000 → v3.1_oag_author.part00171.filtered.jsonl
# ✓ v3.1_oag_author.part00172.jsonl: kept 7138/100000 → v3.1_oag_author.part00172.filtered.jsonl
# ✓ v3.1_oag_author.part00173.jsonl: kept 4242/100000 → v3.1_oag_author.part00173.filtered.jsonl
# ✓ v3.1_oag_author.part00174.jsonl: kept 1993/100000 → v3.1_oag_author.part00174.filtered.jsonl
# ✓ v3.1_oag_author.part00175.jsonl: kept 6097/100000 → v3.1_oag_author.part00175.filtered.jsonl
# ✓ v3.1_oag_author.part00176.jsonl: kept 5911/100000 → v3.1_oag_author.part00176.filtered.jsonl
# ✓ v3.1_oag_author.part00177.jsonl: kept 3451/100000 → v3.1_oag_author.part00177.filtered.jsonl
# ✓ v3.1_oag_author.part00178.jsonl: kept 2011/100000 → v3.1_oag_author.part00178.filtered.jsonl
# ✓ v3.1_oag_author.part00179.jsonl: kept 6916/100000 → v3.1_oag_author.part00179.filtered.jsonl
# ✓ v3.1_oag_author.part00180.jsonl: kept 4794/100000 → v3.1_oag_author.part00180.filtered.jsonl
# ✓ v3.1_oag_author.part00181.jsonl: kept 2572/100000 → v3.1_oag_author.part00181.filtered.jsonl
# ✓ v3.1_oag_author.part00182.jsonl: kept 5097/100000 → v3.1_oag_author.part00182.filtered.jsonl
# ✓ v3.1_oag_author.part00183.jsonl: kept 6331/100000 → v3.1_oag_author.part00183.filtered.jsonl
# ✓ v3.1_oag_author.part00184.jsonl: kept 3824/100000 → v3.1_oag_author.part00184.filtered.jsonl
# ✓ v3.1_oag_author.part00185.jsonl: kept 1168/100000 → v3.1_oag_author.part00185.filtered.jsonl
# ✓ v3.1_oag_author.part00186.jsonl: kept 7323/100000 → v3.1_oag_author.part00186.filtered.jsonl
# ✓ v3.1_oag_author.part00187.jsonl: kept 4871/100000 → v3.1_oag_author.part00187.filtered.jsonl
# ✓ v3.1_oag_author.part00188.jsonl: kept 3042/100000 → v3.1_oag_author.part00188.filtered.jsonl
# ✓ v3.1_oag_author.part00189.jsonl: kept 3947/100000 → v3.1_oag_author.part00189.filtered.jsonl
# ✓ v3.1_oag_author.part00190.jsonl: kept 6894/100000 → v3.1_oag_author.part00190.filtered.jsonl
# ✓ v3.1_oag_author.part00191.jsonl: kept 4002/100000 → v3.1_oag_author.part00191.filtered.jsonl
# ✓ v3.1_oag_author.part00192.jsonl: kept 1451/100000 → v3.1_oag_author.part00192.filtered.jsonl
# ✓ v3.1_oag_author.part00193.jsonl: kept 6838/100000 → v3.1_oag_author.part00193.filtered.jsonl
# ✓ v3.1_oag_author.part00194.jsonl: kept 5197/100000 → v3.1_oag_author.part00194.filtered.jsonl
# ✓ v3.1_oag_author.part00195.jsonl: kept 3601/100000 → v3.1_oag_author.part00195.filtered.jsonl
# ✓ v3.1_oag_author.part00196.jsonl: kept 2920/100000 → v3.1_oag_author.part00196.filtered.jsonl
# ✓ v3.1_oag_author.part00197.jsonl: kept 6839/100000 → v3.1_oag_author.part00197.filtered.jsonl
# ✓ v3.1_oag_author.part00198.jsonl: kept 4223/100000 → v3.1_oag_author.part00198.filtered.jsonl
# ✓ v3.1_oag_author.part00199.jsonl: kept 1993/100000 → v3.1_oag_author.part00199.filtered.jsonl
# ✓ v3.1_oag_author.part00200.jsonl: kept 6026/100000 → v3.1_oag_author.part00200.filtered.jsonl
# ✓ v3.1_oag_author.part00201.jsonl: kept 5862/100000 → v3.1_oag_author.part00201.filtered.jsonl
# ✓ v3.1_oag_author.part00202.jsonl: kept 3496/100000 → v3.1_oag_author.part00202.filtered.jsonl
# ✓ v3.1_oag_author.part00203.jsonl: kept 2087/100000 → v3.1_oag_author.part00203.filtered.jsonl
# ✓ v3.1_oag_author.part00204.jsonl: kept 6920/100000 → v3.1_oag_author.part00204.filtered.jsonl
# ✓ v3.1_oag_author.part00205.jsonl: kept 4763/100000 → v3.1_oag_author.part00205.filtered.jsonl
# ✓ v3.1_oag_author.part00206.jsonl: kept 2662/100000 → v3.1_oag_author.part00206.filtered.jsonl
# ✓ v3.1_oag_author.part00207.jsonl: kept 4950/100000 → v3.1_oag_author.part00207.filtered.jsonl
# ✓ v3.1_oag_author.part00208.jsonl: kept 6529/100000 → v3.1_oag_author.part00208.filtered.jsonl
# ✓ v3.1_oag_author.part00209.jsonl: kept 3943/100000 → v3.1_oag_author.part00209.filtered.jsonl
# ✓ v3.1_oag_author.part00210.jsonl: kept 1089/100000 → v3.1_oag_author.part00210.filtered.jsonl
# ✓ v3.1_oag_author.part00211.jsonl: kept 7374/100000 → v3.1_oag_author.part00211.filtered.jsonl
# ✓ v3.1_oag_author.part00212.jsonl: kept 5027/100000 → v3.1_oag_author.part00212.filtered.jsonl
# ✓ v3.1_oag_author.part00213.jsonl: kept 3035/100000 → v3.1_oag_author.part00213.filtered.jsonl
# ✓ v3.1_oag_author.part00214.jsonl: kept 3735/100000 → v3.1_oag_author.part00214.filtered.jsonl
# ✓ v3.1_oag_author.part00215.jsonl: kept 6927/100000 → v3.1_oag_author.part00215.filtered.jsonl
# ✓ v3.1_oag_author.part00216.jsonl: kept 4017/100000 → v3.1_oag_author.part00216.filtered.jsonl
# ✓ v3.1_oag_author.part00217.jsonl: kept 1578/100000 → v3.1_oag_author.part00217.filtered.jsonl
# ✓ v3.1_oag_author.part00218.jsonl: kept 6924/100000 → v3.1_oag_author.part00218.filtered.jsonl
# ✓ v3.1_oag_author.part00219.jsonl: kept 5312/100000 → v3.1_oag_author.part00219.filtered.jsonl
# ✓ v3.1_oag_author.part00220.jsonl: kept 3574/100000 → v3.1_oag_author.part00220.filtered.jsonl
# ✓ v3.1_oag_author.part00221.jsonl: kept 2817/100000 → v3.1_oag_author.part00221.filtered.jsonl
# ✓ v3.1_oag_author.part00222.jsonl: kept 6834/100000 → v3.1_oag_author.part00222.filtered.jsonl
# ✓ v3.1_oag_author.part00223.jsonl: kept 4255/100000 → v3.1_oag_author.part00223.filtered.jsonl
# ✓ v3.1_oag_author.part00224.jsonl: kept 2058/100000 → v3.1_oag_author.part00224.filtered.jsonl
# ✓ v3.1_oag_author.part00225.jsonl: kept 5918/100000 → v3.1_oag_author.part00225.filtered.jsonl
# ✓ v3.1_oag_author.part00226.jsonl: kept 6156/100000 → v3.1_oag_author.part00226.filtered.jsonl
# ✓ v3.1_oag_author.part00227.jsonl: kept 3568/100000 → v3.1_oag_author.part00227.filtered.jsonl
# ✓ v3.1_oag_author.part00228.jsonl: kept 1775/100000 → v3.1_oag_author.part00228.filtered.jsonl
# ✓ v3.1_oag_author.part00229.jsonl: kept 7026/100000 → v3.1_oag_author.part00229.filtered.jsonl
# ✓ v3.1_oag_author.part00230.jsonl: kept 4874/100000 → v3.1_oag_author.part00230.filtered.jsonl
# ✓ v3.1_oag_author.part00231.jsonl: kept 2678/100000 → v3.1_oag_author.part00231.filtered.jsonl
# ✓ v3.1_oag_author.part00232.jsonl: kept 4642/100000 → v3.1_oag_author.part00232.filtered.jsonl
# ✓ v3.1_oag_author.part00233.jsonl: kept 6710/100000 → v3.1_oag_author.part00233.filtered.jsonl
# ✓ v3.1_oag_author.part00234.jsonl: kept 3642/100000 → v3.1_oag_author.part00234.filtered.jsonl
# ✓ v3.1_oag_author.part00235.jsonl: kept 1266/100000 → v3.1_oag_author.part00235.filtered.jsonl
# ✓ v3.1_oag_author.part00236.jsonl: kept 6934/100000 → v3.1_oag_author.part00236.filtered.jsonl
# ✓ v3.1_oag_author.part00237.jsonl: kept 4778/100000 → v3.1_oag_author.part00237.filtered.jsonl
# ✓ v3.1_oag_author.part00238.jsonl: kept 3567/100000 → v3.1_oag_author.part00238.filtered.jsonl
# ✓ v3.1_oag_author.part00239.jsonl: kept 3327/100000 → v3.1_oag_author.part00239.filtered.jsonl
# ✓ v3.1_oag_author.part00240.jsonl: kept 7027/100000 → v3.1_oag_author.part00240.filtered.jsonl
# ✓ v3.1_oag_author.part00241.jsonl: kept 4083/100000 → v3.1_oag_author.part00241.filtered.jsonl
# ✓ v3.1_oag_author.part00242.jsonl: kept 1830/100000 → v3.1_oag_author.part00242.filtered.jsonl
# ✓ v3.1_oag_author.part00243.jsonl: kept 6363/100000 → v3.1_oag_author.part00243.filtered.jsonl
# ✓ v3.1_oag_author.part00244.jsonl: kept 5785/100000 → v3.1_oag_author.part00244.filtered.jsonl
# ✓ v3.1_oag_author.part00245.jsonl: kept 3496/100000 → v3.1_oag_author.part00245.filtered.jsonl
# ✓ v3.1_oag_author.part00246.jsonl: kept 2389/100000 → v3.1_oag_author.part00246.filtered.jsonl
# ✓ v3.1_oag_author.part00247.jsonl: kept 6922/100000 → v3.1_oag_author.part00247.filtered.jsonl
# ✓ v3.1_oag_author.part00248.jsonl: kept 4772/100000 → v3.1_oag_author.part00248.filtered.jsonl
# ✓ v3.1_oag_author.part00249.jsonl: kept 2615/100000 → v3.1_oag_author.part00249.filtered.jsonl
# ✓ v3.1_oag_author.part00250.jsonl: kept 5212/100000 → v3.1_oag_author.part00250.filtered.jsonl
# ✓ v3.1_oag_author.part00251.jsonl: kept 6481/100000 → v3.1_oag_author.part00251.filtered.jsonl
# ✓ v3.1_oag_author.part00252.jsonl: kept 3779/100000 → v3.1_oag_author.part00252.filtered.jsonl
# ✓ v3.1_oag_author.part00253.jsonl: kept 1261/100000 → v3.1_oag_author.part00253.filtered.jsonl
# ✓ v3.1_oag_author.part00254.jsonl: kept 7153/100000 → v3.1_oag_author.part00254.filtered.jsonl
# ✓ v3.1_oag_author.part00255.jsonl: kept 4954/100000 → v3.1_oag_author.part00255.filtered.jsonl
# ✓ v3.1_oag_author.part00256.jsonl: kept 2977/100000 → v3.1_oag_author.part00256.filtered.jsonl
# ✓ v3.1_oag_author.part00257.jsonl: kept 3963/100000 → v3.1_oag_author.part00257.filtered.jsonl
# ✓ v3.1_oag_author.part00258.jsonl: kept 6816/100000 → v3.1_oag_author.part00258.filtered.jsonl
# ✓ v3.1_oag_author.part00259.jsonl: kept 3951/100000 → v3.1_oag_author.part00259.filtered.jsonl
# ✓ v3.1_oag_author.part00260.jsonl: kept 1539/100000 → v3.1_oag_author.part00260.filtered.jsonl
# ✓ v3.1_oag_author.part00261.jsonl: kept 6784/100000 → v3.1_oag_author.part00261.filtered.jsonl
# ✓ v3.1_oag_author.part00262.jsonl: kept 5111/100000 → v3.1_oag_author.part00262.filtered.jsonl
# ✓ v3.1_oag_author.part00263.jsonl: kept 3608/100000 → v3.1_oag_author.part00263.filtered.jsonl
# ✓ v3.1_oag_author.part00264.jsonl: kept 2915/100000 → v3.1_oag_author.part00264.filtered.jsonl
# ✓ v3.1_oag_author.part00265.jsonl: kept 6881/100000 → v3.1_oag_author.part00265.filtered.jsonl
# ✓ v3.1_oag_author.part00266.jsonl: kept 4293/100000 → v3.1_oag_author.part00266.filtered.jsonl
# ✓ v3.1_oag_author.part00267.jsonl: kept 2053/100000 → v3.1_oag_author.part00267.filtered.jsonl
# ✓ v3.1_oag_author.part00268.jsonl: kept 6173/100000 → v3.1_oag_author.part00268.filtered.jsonl
# ✓ v3.1_oag_author.part00269.jsonl: kept 6019/100000 → v3.1_oag_author.part00269.filtered.jsonl
# ✓ v3.1_oag_author.part00270.jsonl: kept 3566/100000 → v3.1_oag_author.part00270.filtered.jsonl
# ✓ v3.1_oag_author.part00271.jsonl: kept 2001/100000 → v3.1_oag_author.part00271.filtered.jsonl
# ✓ v3.1_oag_author.part00272.jsonl: kept 6883/100000 → v3.1_oag_author.part00272.filtered.jsonl
# ✓ v3.1_oag_author.part00273.jsonl: kept 4794/100000 → v3.1_oag_author.part00273.filtered.jsonl
# ✓ v3.1_oag_author.part00274.jsonl: kept 2596/100000 → v3.1_oag_author.part00274.filtered.jsonl
# ✓ v3.1_oag_author.part00275.jsonl: kept 5320/100000 → v3.1_oag_author.part00275.filtered.jsonl
# ✓ v3.1_oag_author.part00276.jsonl: kept 6629/100000 → v3.1_oag_author.part00276.filtered.jsonl
# ✓ v3.1_oag_author.part00277.jsonl: kept 3855/100000 → v3.1_oag_author.part00277.filtered.jsonl
# ✓ v3.1_oag_author.part00278.jsonl: kept 1064/100000 → v3.1_oag_author.part00278.filtered.jsonl
# ✓ v3.1_oag_author.part00279.jsonl: kept 7213/100000 → v3.1_oag_author.part00279.filtered.jsonl
# ✓ v3.1_oag_author.part00280.jsonl: kept 5250/100000 → v3.1_oag_author.part00280.filtered.jsonl
# ✓ v3.1_oag_author.part00281.jsonl: kept 2412/100000 → v3.1_oag_author.part00281.filtered.jsonl
# ✓ v3.1_oag_author.part00282.jsonl: kept 3682/100000 → v3.1_oag_author.part00282.filtered.jsonl
# ✓ v3.1_oag_author.part00283.jsonl: kept 6530/100000 → v3.1_oag_author.part00283.filtered.jsonl
# ✓ v3.1_oag_author.part00284.jsonl: kept 4101/100000 → v3.1_oag_author.part00284.filtered.jsonl
# ✓ v3.1_oag_author.part00285.jsonl: kept 573/100000 → v3.1_oag_author.part00285.filtered.jsonl
# ✓ v3.1_oag_author.part00286.jsonl: kept 6864/100000 → v3.1_oag_author.part00286.filtered.jsonl
# ✓ v3.1_oag_author.part00287.jsonl: kept 5334/100000 → v3.1_oag_author.part00287.filtered.jsonl
# ✓ v3.1_oag_author.part00288.jsonl: kept 3061/100000 → v3.1_oag_author.part00288.filtered.jsonl
# ✓ v3.1_oag_author.part00289.jsonl: kept 2528/100000 → v3.1_oag_author.part00289.filtered.jsonl
# ✓ v3.1_oag_author.part00290.jsonl: kept 6820/100000 → v3.1_oag_author.part00290.filtered.jsonl
# ✓ v3.1_oag_author.part00291.jsonl: kept 4632/100000 → v3.1_oag_author.part00291.filtered.jsonl
# ✓ v3.1_oag_author.part00292.jsonl: kept 1321/100000 → v3.1_oag_author.part00292.filtered.jsonl
# ✓ v3.1_oag_author.part00293.jsonl: kept 5908/100000 → v3.1_oag_author.part00293.filtered.jsonl
# ✓ v3.1_oag_author.part00294.jsonl: kept 6084/100000 → v3.1_oag_author.part00294.filtered.jsonl
# ✓ v3.1_oag_author.part00295.jsonl: kept 3301/100000 → v3.1_oag_author.part00295.filtered.jsonl
# ✓ v3.1_oag_author.part00296.jsonl: kept 1377/100000 → v3.1_oag_author.part00296.filtered.jsonl
# ✓ v3.1_oag_author.part00297.jsonl: kept 6561/100000 → v3.1_oag_author.part00297.filtered.jsonl
# ✓ v3.1_oag_author.part00298.jsonl: kept 5070/100000 → v3.1_oag_author.part00298.filtered.jsonl
# ✓ v3.1_oag_author.part00299.jsonl: kept 2025/100000 → v3.1_oag_author.part00299.filtered.jsonl
# ✓ v3.1_oag_author.part00300.jsonl: kept 4696/100000 → v3.1_oag_author.part00300.filtered.jsonl
# ✓ v3.1_oag_author.part00301.jsonl: kept 6321/100000 → v3.1_oag_author.part00301.filtered.jsonl
# ✓ v3.1_oag_author.part00302.jsonl: kept 3849/100000 → v3.1_oag_author.part00302.filtered.jsonl
# ✓ v3.1_oag_author.part00303.jsonl: kept 344/100000 → v3.1_oag_author.part00303.filtered.jsonl
# ✓ v3.1_oag_author.part00304.jsonl: kept 7160/100000 → v3.1_oag_author.part00304.filtered.jsonl
# ✓ v3.1_oag_author.part00305.jsonl: kept 5263/100000 → v3.1_oag_author.part00305.filtered.jsonl
# ✓ v3.1_oag_author.part00306.jsonl: kept 2522/100000 → v3.1_oag_author.part00306.filtered.jsonl
# ✓ v3.1_oag_author.part00307.jsonl: kept 3428/100000 → v3.1_oag_author.part00307.filtered.jsonl
# ✓ v3.1_oag_author.part00308.jsonl: kept 6960/100000 → v3.1_oag_author.part00308.filtered.jsonl
# ✓ v3.1_oag_author.part00309.jsonl: kept 3937/100000 → v3.1_oag_author.part00309.filtered.jsonl
# ✓ v3.1_oag_author.part00310.jsonl: kept 1151/100000 → v3.1_oag_author.part00310.filtered.jsonl
# ✓ v3.1_oag_author.part00311.jsonl: kept 6711/100000 → v3.1_oag_author.part00311.filtered.jsonl
# ✓ v3.1_oag_author.part00312.jsonl: kept 5277/100000 → v3.1_oag_author.part00312.filtered.jsonl
# ✓ v3.1_oag_author.part00313.jsonl: kept 3657/100000 → v3.1_oag_author.part00313.filtered.jsonl
# ✓ v3.1_oag_author.part00314.jsonl: kept 2699/100000 → v3.1_oag_author.part00314.filtered.jsonl
# ✓ v3.1_oag_author.part00315.jsonl: kept 6968/100000 → v3.1_oag_author.part00315.filtered.jsonl
# ✓ v3.1_oag_author.part00316.jsonl: kept 4416/100000 → v3.1_oag_author.part00316.filtered.jsonl
# ✓ v3.1_oag_author.part00317.jsonl: kept 2080/100000 → v3.1_oag_author.part00317.filtered.jsonl
# ✓ v3.1_oag_author.part00318.jsonl: kept 5928/100000 → v3.1_oag_author.part00318.filtered.jsonl
# ✓ v3.1_oag_author.part00319.jsonl: kept 6016/100000 → v3.1_oag_author.part00319.filtered.jsonl
# ✓ v3.1_oag_author.part00320.jsonl: kept 3559/100000 → v3.1_oag_author.part00320.filtered.jsonl
# ✓ v3.1_oag_author.part00321.jsonl: kept 1808/100000 → v3.1_oag_author.part00321.filtered.jsonl
# ✓ v3.1_oag_author.part00322.jsonl: kept 7120/100000 → v3.1_oag_author.part00322.filtered.jsonl
# ✓ v3.1_oag_author.part00323.jsonl: kept 4891/100000 → v3.1_oag_author.part00323.filtered.jsonl
# ✓ v3.1_oag_author.part00324.jsonl: kept 2783/100000 → v3.1_oag_author.part00324.filtered.jsonl
# ✓ v3.1_oag_author.part00325.jsonl: kept 4537/100000 → v3.1_oag_author.part00325.filtered.jsonl
# ✓ v3.1_oag_author.part00326.jsonl: kept 6745/100000 → v3.1_oag_author.part00326.filtered.jsonl
# ✓ v3.1_oag_author.part00327.jsonl: kept 3828/100000 → v3.1_oag_author.part00327.filtered.jsonl
# ✓ v3.1_oag_author.part00328.jsonl: kept 1233/100000 → v3.1_oag_author.part00328.filtered.jsonl
# ✓ v3.1_oag_author.part00329.jsonl: kept 7230/100000 → v3.1_oag_author.part00329.filtered.jsonl
# ✓ v3.1_oag_author.part00330.jsonl: kept 4978/100000 → v3.1_oag_author.part00330.filtered.jsonl
# ✓ v3.1_oag_author.part00331.jsonl: kept 3615/100000 → v3.1_oag_author.part00331.filtered.jsonl
# ✓ v3.1_oag_author.part00332.jsonl: kept 3270/100000 → v3.1_oag_author.part00332.filtered.jsonl
# ✓ v3.1_oag_author.part00333.jsonl: kept 7183/100000 → v3.1_oag_author.part00333.filtered.jsonl
# ✓ v3.1_oag_author.part00334.jsonl: kept 4106/100000 → v3.1_oag_author.part00334.filtered.jsonl
# ✓ v3.1_oag_author.part00335.jsonl: kept 1893/100000 → v3.1_oag_author.part00335.filtered.jsonl
# ✓ v3.1_oag_author.part00336.jsonl: kept 6450/100000 → v3.1_oag_author.part00336.filtered.jsonl
# ✓ v3.1_oag_author.part00337.jsonl: kept 5804/100000 → v3.1_oag_author.part00337.filtered.jsonl
# ✓ v3.1_oag_author.part00338.jsonl: kept 3440/100000 → v3.1_oag_author.part00338.filtered.jsonl
# ✓ v3.1_oag_author.part00339.jsonl: kept 2174/100000 → v3.1_oag_author.part00339.filtered.jsonl
# ✓ v3.1_oag_author.part00340.jsonl: kept 7024/100000 → v3.1_oag_author.part00340.filtered.jsonl
# ✓ v3.1_oag_author.part00341.jsonl: kept 4650/100000 → v3.1_oag_author.part00341.filtered.jsonl
# ✓ v3.1_oag_author.part00342.jsonl: kept 2492/100000 → v3.1_oag_author.part00342.filtered.jsonl
# ✓ v3.1_oag_author.part00343.jsonl: kept 5289/100000 → v3.1_oag_author.part00343.filtered.jsonl
# ✓ v3.1_oag_author.part00344.jsonl: kept 6553/100000 → v3.1_oag_author.part00344.filtered.jsonl
# ✓ v3.1_oag_author.part00345.jsonl: kept 3863/100000 → v3.1_oag_author.part00345.filtered.jsonl
# ✓ v3.1_oag_author.part00346.jsonl: kept 1069/100000 → v3.1_oag_author.part00346.filtered.jsonl
# ✓ v3.1_oag_author.part00347.jsonl: kept 7117/100000 → v3.1_oag_author.part00347.filtered.jsonl
# ✓ v3.1_oag_author.part00348.jsonl: kept 4995/100000 → v3.1_oag_author.part00348.filtered.jsonl
# ✓ v3.1_oag_author.part00349.jsonl: kept 3093/100000 → v3.1_oag_author.part00349.filtered.jsonl
# ✓ v3.1_oag_author.part00350.jsonl: kept 3856/100000 → v3.1_oag_author.part00350.filtered.jsonl
# ✓ v3.1_oag_author.part00351.jsonl: kept 6924/100000 → v3.1_oag_author.part00351.filtered.jsonl
# ✓ v3.1_oag_author.part00352.jsonl: kept 3965/100000 → v3.1_oag_author.part00352.filtered.jsonl
# ✓ v3.1_oag_author.part00353.jsonl: kept 1629/100000 → v3.1_oag_author.part00353.filtered.jsonl
# ✓ v3.1_oag_author.part00354.jsonl: kept 6705/100000 → v3.1_oag_author.part00354.filtered.jsonl
# ✓ v3.1_oag_author.part00355.jsonl: kept 5316/100000 → v3.1_oag_author.part00355.filtered.jsonl
# ✓ v3.1_oag_author.part00356.jsonl: kept 3597/100000 → v3.1_oag_author.part00356.filtered.jsonl
# ✓ v3.1_oag_author.part00357.jsonl: kept 705/74511 → v3.1_oag_author.part00357.filtered.jsonl
#
# ==== Done ====
# Total kept: 1592379 / 35774511 (4.45%)
